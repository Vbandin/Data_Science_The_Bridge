# %% [markdown]
# # Bases de datos en Python

# %% [markdown]
# ## Índice
# 1. [Acceso a bases de datos relacionales](#sql)
# 2. [Crear bases de datos relacionales](#crear)
# 3. [Bases de datos NoSQL](#nosql)

# %% [markdown]
# <a id="sql"></a>
# ## Acceso a bases de datos relacionales

# %% [markdown]
# Podemos acceder a bases de datos SQL con la librería `pymysql`. Para instalarla escribimos en Anaconda Prompt:
# `conda install -c anaconda pymysql`

# %%
import pymysql

# %% [markdown]
# #### Ejemplo 1
# Vamos a conectarnos a la base de datos NBA, que contiene estadísticas de partidos de una temporada.
# Utilizaremos los siguientes parámetros:
# * servidor: relational.fit.cvut.cz
# * usuario: guest
# * contraseña: relational
# * base de datos: NBA

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Vamos a crear una conexión con la base de datos

# %%
database_host = 'relational.fit.cvut.cz'
username = 'guest'
password = 'relational'
database_name = 'NBA'

db = pymysql.connect(host=database_host,
                     user=username,
                     password=password,
                     database=database_name)
cursor = db.cursor()

# %% [markdown]
# La función `connect()` crea una conexión a la base de datos. Un *cursor* nos permite realizar operaciones con los datos almacenados en la base de datos.
#
# <img src='https://i.ibb.co/L8HH0G5/cursor.png'>
#
# Una vez creado el cursor, podemos empezar a ejecutar comandos sobre el contenido de la base de datos utilizando el métido `execute()`,
#
# Al ejecutar queries, utilizamos los métodos `fetchone()` (primera fila) o `fectchall()` (todas las filas) para visizar los resultados de las consultas. Para cerrar la conexión, utilizamso el método `close()`

# %%
cursor.execute("SELECT * FROM Player")
cursor.fetchall()
# Out:
# ((1, 'Nicolas Batum'),
#  (2, 'LaMarcus Aldridge'),
#  (3, 'Robin Lopez'),
#  (4, 'Wesley Matthews'),
#  (5, 'Damian Lillard'),
#  (6, 'Thomas Robinson'),
#  (7, 'Maurice Williams'),
#  (8, 'Will Barton'),
#  (9, 'Dorell Wright'),
#  (10, 'Earl Watson'),
#  (11, 'CJ McCollum'),
#  (12, 'Meyers Leonard'),
#  (13, 'Victor Claver'),
#  (14, 'Kent Bazemore'),
#  (15, 'Pau Gasol'),
#  (16, 'Chris Kaman'),
#  (17, 'Jodie Meeks'),
#  (18, 'Kendall Marshall'),
#  (19, 'Steve Nash'),
#  (20, 'Xavier Henry'),
#  (21, 'Robert Sacre'),
#  (22, 'Ryan Kelly'),
#  (23, 'Nick Young'),
#  (24, 'Marshon Brooks'),
#  (25, 'Jordan Hill'),
#  (26, 'Wesley Johnson'),
#  (27, 'Andre Iguodala'),
#  (28, 'Draymond Green'),
#  (29, "Jermaine O'Neal"),
#  (30, 'Klay Thompson'),
#  (31, 'Stephen Curry'),
#  (32, 'Marreese Speights'),
#  (33, 'Harrison Barnes'),
#  (34, 'Steve Blake'),
#  (35, 'Jordan Crawford'),
#  (36, 'Hilton Armstrong'),
#  (37, 'Andrew Bogut'),
#  (38, 'David Lee'),
#  (39, 'Shawn Marion'),
#  (40, 'Dirk Nowitzki'),
#  (41, 'Samuel Dalembert'),
#  (42, 'Monta Ellis'),
#  (43, 'Jose Calderon'),
#  (44, 'Vince Carter'),
#  (45, 'Brandan Wright'),
#  (46, 'Devin Harris'),
#  (47, 'Jae Crowder'),
#  (48, 'DeJuan Blair'),
#  (49, 'Wayne Ellington'),
#  (50, 'Bernard James'),
#  (51, 'Shane Larkin'),
#  (52, 'Chandler Parsons'),
#  (53, 'Donatas Motiejunas'),
#  (54, 'Omer Asik'),
#  (55, 'James Harden'),
#  (56, 'Jeremy Lin'),
#  (57, 'Omri Casspi'),
#  (58, 'Francisco Garcia'),
#  (59, 'Isaiah Canaan'),
#  (60, 'Jordan Hamilton'),
#  (61, 'Patrick Beverley'),
#  (62, 'Dwight Howard'),
#  (63, 'Terrence Jones'),
#  (64, 'Greg Smith'),
#  (65, 'Joe Johnson'),
#  (66, 'Paul Pierce'),
#  (67, 'Mason Plumlee'),
#  (68, 'Shaun Livingston'),
#  (69, 'Deron Williams'),
#  (70, 'Alan Anderson'),
#  (71, 'Andray Blatche'),
#  (72, 'Mizra Teletovic'),
#  (73, 'Jorge Gutierrez'),
#  (74, 'Marquis Teague'),
#  (75, 'Jason Collins'),
#  (76, 'Andrei Kirilenko'),
#  (77, 'Marcus Thornton'),
#  (78, 'JR Smith'),
#  (79, 'Carmelo Anthony'),
#  (80, 'Tyson Chandler'),
#  (81, 'Iman Shumpert'),
#  (82, 'Raymond Felton'),
#  (83, 'Timothy Hardaway Jr.'),
#  (84, 'Pablo Prigioni'),
#  (85, 'Cole Aldrich'),
#  (86, 'Jeremy Tyler'),
#  (87, 'Shannon Brown'),
#  (88, 'Toure Murry'),
#  (89, "Amar'e Stoudemire"),
#  (90, 'Richard Jefferson'),
#  (91, 'Marvin Williams'),
#  (92, 'Derrick Favors'),
#  (93, 'Gordon Hayward'),
#  (94, 'Trey Burke'),
#  (95, 'Enes Kanter'),
#  (96, 'Alec Burks'),
#  (97, 'Diante Garrett'),
#  (98, 'Ian Clark'),
#  (99, 'Rudy Gobert'),
#  (100, 'Jeremy Evans'),
#  (101, 'John Lucas III'),
#  (102, 'Brandon Rush'),
#  (103, 'Tayshaun Prince'),
#  (104, 'Zach Randolph'),
#  (105, 'Marc Gasol'),
#  (106, 'Courtney Lee'),
#  (107, 'Mike Conley'),
#  (108, 'Nick Calathes'),
#  (109, 'Ed Davis'),
#  (110, 'Mike Miller'),
#  (111, 'Kosta Koufos'),
#  (112, 'Tony Allen'),
#  (113, 'James Johnson'),
#  (114, 'Jon Leuer'),
#  (115, 'Beno Udrih'),
#  (116, 'Quincy Miller'),
#  (117, 'Kenneth Faried'),
#  (118, 'Timofey Mozgov'),
#  (119, 'Randy Foye'),
#  (120, 'Ty Lawson'),
#  (121, 'Darrell Arthur'),
#  (122, 'Evan Fournier'),
#  (123, 'Aaron Brooks'),
#  (124, 'Jan Vesely'),
#  (125, 'Wilson Chandler'),
#  (126, 'JJ Hickson'),
#  (127, 'Anthony Randolph'),
#  (128, 'Nate Robinson'),
#  (129, 'Rudy Gay'),
#  (130, 'Reggie Evans'),
#  (131, 'DeMarcus Cousins'),
#  (132, 'Ben McLemore'),
#  (133, 'Ray McCallum'),
#  (134, 'Travis Outlaw'),
#  (135, 'Derrick Williams'),
#  (136, 'Jared Cunningham'),
#  (137, 'Jason Thompson'),
#  (138, 'Quincy Acy'),
#  (139, 'Aaron Gray'),
#  (140, 'Isaiah Thomas'),
#  (141, 'Al-Farouq Aminu'),
#  (142, 'Anthony Davis'),
#  (143, 'Greg Stiemsma'),
#  (144, 'Tyreke Evans'),
#  (145, 'Brian Roberts'),
#  (146, 'Darius Miller'),
#  (147, 'Alexis Ajinca'),
#  (148, 'Austin Rivers'),
#  (149, 'Anthony Morrow'),
#  (150, 'Jeff Withey'),
#  (151, 'Luke Babbitt'),
#  (152, 'Eric Gordon'),
#  (153, 'Jason Smith'),
#  (154, 'Matt Barnes'),
#  (155, 'Jared Dudley'),
#  (156, 'DeAndre Jordan'),
#  (157, 'Darren Collison'),
#  (158, 'Chris Paul'),
#  (159, 'Hidayet Turkoglu'),
#  (160, 'Willie Green'),
#  (161, 'Reggie Bullock'),
#  (162, 'Ryan Hollins'),
#  (163, 'Glen Davis'),
#  (164, 'Jamal Crawford'),
#  (165, 'Danny Granger'),
#  (166, 'Blake Griffin'),
#  (167, 'Corey Brewer'),
#  (168, 'Kevin Love'),
#  (169, 'Hidayet Turkoglu'),
#  (170, 'Kevin Martin'),
#  (171, 'Ricky Rubio'),
#  (172, 'Gorgui Dieng'),
#  (173, 'Jose Barea'),
#  (174, 'Dante Cunningham'),
#  (175, 'Chase Budinger'),
#  (176, 'Robbie Hummel'),
#  (177, 'Shabazz Muhammad'),
#  (178, 'Luc Mbah a Moute'),
#  (179, 'Alexey Shved'),
#  (180, 'Jeff Green'),
#  (181, 'Brandon Bass'),
#  (182, 'Kris Humphries'),
#  (183, 'Avery Bradley'),
#  (184, 'Jerryd Bayless'),
#  (185, 'Jared Sullinger'),
#  (186, 'Christapher Johnson'),
#  (187, 'Phil Pressey'),
#  (188, 'Kelly Olynyk'),
#  (189, 'Chris Babb'),
#  (190, 'Joel Anthony'),
#  (191, 'Rajon Rondo'),
#  (192, 'Mike Dunleavy'),
#  (193, 'Carlos Boozer'),
#  (194, 'Joakim Noah'),
#  (195, 'Jimmy Butler'),
#  (196, 'Kirk Hinrich'),
#  (197, 'DJ Augustin'),
#  (198, 'Taj Gibson'),
#  (199, 'Nazr Mohammed'),
#  (200, 'Tony Snell'),
#  (201, 'Jimmer Fredette'),
#  (202, 'Erik Murphy'),
#  (203, 'Tornike Shengelia'),
#  (204, 'Terrence Ross'),
#  (205, 'Amir Johnson'),
#  (206, 'Jonas Valanciunas'),
#  (207, 'Demar DeRozan'),
#  (208, 'Kyle Lowry'),
#  (209, 'Patrick Patterson'),
#  (210, 'Steve Novak'),
#  (211, 'John Salmons'),
#  (212, 'Greivis Vasquez'),
#  (213, 'Chuck Hayes'),
#  (214, 'Nando De Colo'),
#  (215, 'Landry Fields'),
#  (216, 'Tyler Hansbrough'),
#  (217, 'Lebron James'),
#  (218, 'Udonis Haslem'),
#  (219, 'Chris Bosh'),
#  (220, 'Toney Douglas'),
#  (221, 'Mario Chalmers'),
#  (222, 'Rashad Lewis'),
#  (223, 'Norris Cole'),
#  (224, 'James Jones'),
#  (225, 'Chris Andersen'),
#  (226, 'Shane Battier'),
#  (227, 'Michael Beasley'),
#  (228, 'Justin Hamilton'),
#  (229, 'Dwayne Wade'),
#  (230, 'Khris Middleton'),
#  (231, 'Jeff Adrien'),
#  (232, 'Zaza Pachulia'),
#  (233, 'Ramon Sessions'),
#  (234, 'Brandon Knight'),
#  (235, 'Giannis Antetokounmpo'),
#  (236, 'John Henson'),
#  (237, 'Ekpe Udoh'),
#  (238, 'Ersan Ilyasova'),
#  (239, 'OJ Mayo'),
#  (240, 'Miroslav Raduljica'),
#  (241, 'DJ Stephens'),
#  (242, 'Nate Wolters'),
#  (243, 'Josh Smith'),
#  (244, 'Greg Monroe'),
#  (245, 'Andre Drummond'),
#  (246, 'Kyle Singler'),
#  (247, 'Brandon Jennings'),
#  (248, 'Rodney Stuckey'),
#  (249, 'Jonas Jerebko'),
#  (250, 'Kentavious Caldwell-Pope'),
#  (251, 'Will Bynum'),
#  (252, 'Charlie Villanueva'),
#  (253, 'Luigi Datome'),
#  (254, 'Tony Mitchell'),
#  (255, 'Peyton Siva'),
#  (256, 'Hollis Thompson'),
#  (257, 'Thaddeus Young'),
#  (258, 'Henry Sims'),
#  (259, 'James Anderson'),
#  (260, 'Michael Carter-Williams'),
#  (261, 'Tony Wroten'),
#  (262, 'Jarvis Varnado'),
#  (263, 'Elliot Williams'),
#  (264, 'Casper Ware'),
#  (265, 'Brandon Davies'),
#  (266, 'Arnett Moultrie'),
#  (267, 'James Nunnally'),
#  (268, 'DeMarre Carroll'),
#  (269, 'Paul Millsap'),
#  (270, 'Pero Antic'),
#  (271, 'Kyle Korver'),
#  (272, 'Jeff Teague'),
#  (273, 'Louis Williams'),
#  (274, 'Elton Brand'),
#  (275, 'Mike Scott'),
#  (276, 'Dennis Schroder'),
#  (277, 'Mike Muscala'),
#  (278, 'Shelvin Mack'),
#  (279, 'Cartier Martin'),
#  (280, 'Trevor Ariza'),
#  (281, 'Trevor Booker'),
#  (282, 'Marcin Gortat'),
#  (283, 'Bradley Beal'),
#  (284, 'John Wall'),
#  (285, 'Drew Gooden'),
#  (286, 'Martell Webster'),
#  (287, 'Al Harrington'),
#  (288, 'Andre Miller'),
#  (289, 'Kevin Seraphin'),
#  (290, 'Otto Porter'),
#  (291, 'Chris Singleton'),
#  (292, 'Garrett Temple'),
#  (293, 'Michael Kidd-Gilchrist'),
#  (294, 'Josh McRoberts'),
#  (295, 'Al Jefferson'),
#  (296, 'Gerald Henderson'),
#  (297, 'Kemba Walker'),
#  (298, 'Cody Zeller'),
#  (299, 'Bismack Biyombo'),
#  (300, 'Gary Neal'),
#  (301, 'Luke Ridnour'),
#  (302, 'Chris Douglas-Roberts'),
#  (303, 'Jannero Pargo'),
#  (304, 'Anthony Tolliver'),
#  (305, 'DJ White'),
#  (306, 'Paul George'),
#  (307, 'David West'),
#  (308, 'Roy Hibbert'),
#  (309, 'Lance Stephenson'),
#  (310, 'George Hill'),
#  (311, 'Luis Scola'),
#  (312, 'Evan Turner'),
#  (313, 'Ian Mahinmi'),
#  (314, 'Rasual Butler'),
#  (315, 'Donald Sloan'),
#  (316, 'Lavoy Allen'),
#  (317, 'Chris Copeland'),
#  (318, 'Solomon Hill'),
#  (319, 'Luol Deng'),
#  (320, 'Tristan Thompson'),
#  (321, 'Spencer Hawes'),
#  (322, 'Dion Waiters'),
#  (323, 'Kyrie Irving'),
#  (324, 'Jarrett Jack'),
#  (325, 'Matthew Dellavedova'),
#  (326, 'Tyler Zeller'),
#  (327, 'Alonzo Gee'),
#  (328, 'Sergey Karasev'),
#  (329, 'Scotty Hopson'),
#  (330, 'Anderson Varejao'),
#  (331, 'Maurice Harkless'),
#  (332, "Kyle O'Quinn"),
#  (333, 'Nikola Vucevic'),
#  (334, 'Arron Afflalo'),
#  (335, 'Jameer Nelson'),
#  (336, 'Andrew Nicholson'),
#  (337, 'Victor Oladipo'),
#  (338, 'Etwaun Moore'),
#  (339, 'Tobias Harris'),
#  (340, 'Doron Lamb'),
#  (341, 'Dewayne Dedmon'),
#  (342, 'Jason Maxiell'),
#  (343, 'Ronnie Price'),
#  (344, 'Julyan Stone'),
#  (345, 'Ray Allen'),
#  (346, 'Ronny Turiaf'),
#  (347, 'Kawhi Leonard'),
#  (348, 'Tim Duncan'),
#  (349, 'Boris Diaw'),
#  (350, 'Daniel Green'),
#  (351, 'Tony Parker'),
#  (352, 'Emanuel Ginobli'),
#  (353, 'Tiago Splitter'),
#  (354, 'Patrick Mills'),
#  (355, 'Marco Belinelli'),
#  (356, 'Jeff Ayres'),
#  (357, 'Cory Joseph'),
#  (358, 'Aron Baynes'),
#  (359, 'Austin Daye'),
#  (360, 'PJ Tucker'),
#  (361, 'Channing Frye'),
#  (362, 'Miles Plumlee'),
#  (363, 'Goran Dragic'),
#  (364, 'Eric Bledsoe'),
#  (365, 'Gerald Green'),
#  (366, 'Markieff Morris'),
#  (367, 'Marcus Morris'),
#  (368, 'Ish Smith'),
#  (369, 'Dionte Christmas'),
#  (370, 'Archie Goodwin'),
#  (371, 'Alex Len'),
#  (372, 'Shavlik Randolph'),
#  (373, 'Orlando Johnson'),
#  (374, 'Royce White'),
#  (375, 'Damion James'),
#  (376, 'Kevin Durant'),
#  (377, 'Serge Ibaka'),
#  (378, 'Kendrick Perkins'),
#  (379, 'Andre Roberson'),
#  (380, 'Russell Westbrook'),
#  (381, 'Caron Butler'),
#  (382, 'Steven Adams'),
#  (383, 'Nick Collison'),
#  (384, 'Reggie Jackson'),
#  (385, 'Derek Fisher'),
#  (386, 'Jeremy Lamb'),
#  (387, 'Perry Jones'),
#  (388, 'Hasheem Thabeet'),
#  (389, 'JJ Redick'),
#  (390, 'Dwight Buycks'),
#  (391, 'David Lee'),
#  (392, 'Nikola Pekovic'))

# %% [markdown]
# Podemos ver las tablas de la base de datos con la query `SHOW TABLES`

# %%
cursor.execute('SHOW TABLES')
cursor.fetchall()
# Out:
# (('Actions',),
#  ('Game',),
#  ('Player',),
#  ('Team',),
#  ('joined_drafted_all_players_original',))

# %%
cursor.close()

# %% [markdown]
# La función `read_sql()` de pandas nos permite crear dataframes a partir de queries. Con este método no es necesario crear un cursor

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore') # Esconde los warnings
query = "SELECT * FROM Actions"
df = pd.read_sql(query,db)
df
# Out:
#      GameId  TeamId  PlayerId  Minutes  FieldGoalsMade  FieldGoalAttempts  \
# 0         1       7        78     2605               5                 14
# 1         1       7        79     2359              11                 19
# 2         1       7        80     2104               6                  7
# 3         1       7        81     1392               1                  5
# 4         1       7        82     2124               5                  8
# ..      ...     ...       ...      ...             ...                ...
# 762      30      25       316        0               0                  0
# 763      30      25       317        0               0                  0
# 764      30      25       318        0               0                  0
# 765      30      17       344        0               0                  0
# 766      30      17       390        0               0                  0
#
#      3PointsMade  3PointAttempts  FreeThrowsMade  FreeThrowAttempts  ...  \
# 0              3               3               0                  0  ...
# 1              3               3               8                  8  ...
# 2              3               3               3                  8  ...
# 3              3               3               0                  0  ...
# 4              3               3               1                  2  ...
# ..           ...             ...             ...                ...  ...
# 762            3               3               0                  0  ...
# 763            3               3               0                  0  ...
# 764            3               3               0                  0  ...
# 765            3               3               0                  0  ...
# 766            3               3               0                  0  ...
#
#      DefensiveRebounds  TotalRebounds  Assists  PersonalFouls  Steals  \
# 0                    3              3        4              2       1
# 1                    8              8        3              2       3
# 2                    7              9        1              3       1
# 3                    2              2        0              4       1
# 4                    3              3        6              1       1
# ..                 ...            ...      ...            ...     ...
# 762                  0              0        0              0       0
# 763                  0              0        0              0       0
# 764                  0              0        0              0       0
# 765                  0              0        0              0       0
# 766                  0              0        0              0       0
#
#      Turnovers  BlockedShots  BlocksAgainst  Points  Starter
# 0            1             0              0      13        1
# 1            3             1              0      34        1
# 2            1             2              0      15        1
# 3            0             0              0       2        1
# 4            4             0              0      12        1
# ..         ...           ...            ...     ...      ...
# 762          0             0              0       0        0
# 763          0             0              0       0        0
# 764          0             0              0       0        0
# 765          0             0              0       0        0
# 766          0             0              0       0        0
#
# [767 rows x 22 columns]

# %% [markdown]
# Obtenemos los jugadores con más de 5 asistencias en algún partido

# %%
query = '''
SELECT PlayerName, Assists
FROM Actions
JOIN Player
ON Actions.PlayerId = Player.PlayerId
WHERE Assists > 5
ORDER BY Assists DESC
'''
Asistencias5 = pd.read_sql(query,db)
Asistencias5
# Out:
#           PlayerName  Assists
# 0   Brandon Jennings       13
# 1          Ty Lawson       12
# 2     Ramon Sessions       11
# 3      Blake Griffin       11
# 4        DJ Augustin       11
# ..               ...      ...
# 64    Raymond Felton        6
# 65       Rajon Rondo        6
# 66     Zaza Pachulia        6
# 67      Phil Pressey        6
# 68    Deron Williams        6
#
# [69 rows x 2 columns]

# %% [markdown]
# Obtenemos el TOP 10 jugadores con más asistencias en la temporada

# %%
query = '''
SELECT PlayerName, SUM(Assists) AS TotalAssists
FROM Actions ACT
JOIN Player PLA
ON ACT.PlayerId = PLA.PlayerId
GROUP BY PlayerName
ORDER BY TotalAssists DESC
LIMIT 10
'''
TopTenAsistencias = pd.read_sql(query,db)
TopTenAsistencias
# Out:
#          PlayerName  TotalAssists
# 0        Chris Paul          27.0
# 1      Kemba Walker          25.0
# 2  Brandon Jennings          22.0
# 3         Ty Lawson          21.0
# 4     Demar DeRozan          20.0
# 5    Ramon Sessions          17.0
# 6      Andre Miller          17.0
# 7      Lebron James          16.0
# 8       DJ Augustin          16.0
# 9         John Wall          16.0

# %% [markdown]
# Obtenemos el TOP 10 Equipos con más puntuación media por partido

# %%
query = '''
SELECT TeamName,
       AVG(TotalPoints) AS AvgPoints
FROM(
    SELECT TeamName, GameId, SUM(Points) AS TotalPoints
    FROM Actions
    JOIN Team
    ON Actions.TeamId = Team.TeamId
    GROUP BY TeamName, GameId
    )T1
GROUP BY TeamName
ORDER BY AvgPoints DESC
LIMIT 10
'''
TopTenAsistencias = pd.read_sql(query,db)
TopTenAsistencias
# Out:
#                  TeamName  AvgPoints
# 0  Portland Trail Blazers   124.0000
# 1     Cleveland Cavaliers   119.0000
# 2        Dallas Mavericks   116.5000
# 3   Golden State Warriors   112.5000
# 4    Los Angeles Clippers   111.0000
# 5       Charlotte Bobcats   108.3333
# 6            Phoenix Suns   108.0000
# 7          Denver Nuggets   107.0000
# 8      Los Angeles Lakers   107.0000
# 9   Oklahoma City Thunder   106.0000

# %% [markdown]
# #### Ejemplo 2
# Vamos a conectarnos a la base de datos de los empleados de una empresa
# * servidor: relational.fit.cvut.cz
# * usuario: guest
# * contraseña: relational
# * base de datos: employees
# ![image.png](attachment:image.png)

# %%
database_host = 'relational.fit.cvut.cz'
username = 'guest'
password = 'relational'
database_name = 'employee'

db = pymysql.connect(host=database_host,
                     user=username,
                     password=password,
                     database=database_name)

# %% [markdown]
# Obtener el salario máximo, mínimo y medio por género y cargo

# %%
query = '''
SELECT * FROM employees
LIMIT 10
'''

pd.read_sql(query,db)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel     Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto    Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 5   10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 6   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 7   10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 8   10009  1952-04-19     Sumant       Peac      F  1985-02-18
# 9   10010  1963-06-01  Duangkaew   Piveteau      F  1989-08-24

# %%
query_5 = '''
SELECT COUNT(distinct emp_no)
FROM titles
WHERE title = 'Manager'
AND to_date = '9999-01-01'
'''
# Miramos cuantos Engineers hay en la empresa
## Usamos el 'distinct' para que nos cuente solo los elementos distintos
manager = pd.read_sql(query_5, db)
manager
# Out:
#    COUNT(distinct emp_no)
# 0                       9

# %%
query = '''
SELECT * FROM titles
LIMIT 10
'''

pd.read_sql(query,db)
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01
# 5   10005     Senior Staff  1996-09-12  9999-01-01
# 6   10005            Staff  1989-09-12  1996-09-12
# 7   10006  Senior Engineer  1990-08-05  9999-01-01
# 8   10007     Senior Staff  1996-02-11  9999-01-01
# 9   10007            Staff  1989-02-10  1996-02-11

# %%
query = '''
SELECT title, gender, MIN(salary), AVG(salary), MAX(salary), COUNT(salary)
FROM employees emp
JOIN salaries sal
ON  emp.emp_no = sal.emp_no
JOIN titles tit
ON emp.emp_no = tit.emp_no
WHERE sal.to_date = '9999-01-01'
AND tit.to_date = '9999-01-01'
GROUP BY title, gender
'''

Salario = pd.read_sql(query,db)
Salario
# Out:
#                  title gender  MIN(salary)  AVG(salary)  MAX(salary)  \
# 0   Assistant Engineer      M        39827   57197.9674       117636
# 1   Assistant Engineer      F        39469   57495.9861       106340
# 2             Engineer      M        38942   59592.9683       130939
# 3             Engineer      F        39519   59617.3549       115444
# 4              Manager      M        56654   79350.6000       106491
# 5              Manager      F        65400   75690.0000        83457
# 6      Senior Engineer      M        39285   70869.9085       140784
# 7      Senior Engineer      F        39476   70753.8341       138273
# 8         Senior Staff      M        39012   80735.4795       158220
# 9         Senior Staff      F        39227   80662.9816       152710
# 10               Staff      M        39186   67362.1754       133577
# 11               Staff      F        38936   67282.4599       137875
# 12    Technique Leader      M        38623   67599.6710       132233
# 13    Technique Leader      F        39812   67369.0734       144434
#
#     COUNT(salary)
# 0            2148
# 1            1440
# 2           18571
# 3           12412
# 4               5
# 5               4
# 6           51533
# 7           34406
# 8           49232
# 9           32792
# 10          15436
# 11          10090
# 12           7189
# 13           4866

# %%
query_5 = '''
SELECT COUNT(distinct emp_no)
FROM titles
WHERE title = 'Manager'
AND to_date = '9999-01-01'
'''
# Miramos cuantos Engineers hay en la empresa
## Usamos el 'distinct' para que nos cuente solo los elementos distintos
manager = pd.read_sql(query_5, db)
manager
# Out:
#    COUNT(distinct emp_no)
# 0                       9

# %% [markdown]
# <a id="crear"></a>
# ## Crear bases de datos relacionales

# %% [markdown]
# Podemos crear nuestras propias bases de datos utilizando SQLite

# %%
import sqlite3

# %%
conn = sqlite3.connect('my_database.sqlite')
cursor = conn.cursor()

# %% [markdown]
# Podemos crear tablas con el comando `CREATE TABLE`

# %%
cursor.execute('''
CREATE TABLE SCHOOL
(ID INT PRIMARY KEY NOT NULL,
 NAME TEXT NOT NULL,
 AGE INT NOT NULL,
 CITY CHAR(50),
 MARKS INT
 )
''')

# %% [markdown]
# Para insertar valores usamos `INSERT INTO`. Siempre que hagamos un cambio en nuestra base de datos, tenemos que confirmarlo utilizando `commit()`

# %%
cursor.execute('''
INSERT INTO SCHOOL (ID,NAME,AGE,CITY,MARKS) 
                    VALUES(1,"Luis",24,"Madrid",8)
''')

cursor.execute('''
INSERT INTO SCHOOL (ID,NAME,AGE,CITY,MARKS) 
                    VALUES(2,"Ana",34,"Bilbao",9)
''')

cursor.execute('''
INSERT INTO SCHOOL (ID,NAME,AGE,CITY,MARKS) 
                    VALUES(3,"Pedro",19,"Santander",10)
''')

conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20304\1707114447.py in <module>
# ----> 1 cursor.execute('''
#       2 INSERT INTO SCHOOL (ID,NAME,AGE,CITY,MARKS)
#       3                     VALUES(1,"Luis",24,"Madrid",8)
#       4 ''')
#       5
#
# IntegrityError: UNIQUE constraint failed: SCHOOL.ID

# %%
pd.read_sql("SELECT * FROM SCHOOL", conn)
# Out:
#    ID   NAME  AGE       CITY  MARKS
# 0   1   Luis   24     Madrid      8
# 1   2    Ana   34     Bilbao      9
# 2   3  Pedro   19  Santander     10

# %% [markdown]
# También podemos crear tablas a partir de dataframes

# %%
Salario.to_sql('SALARY', conn, index=False)
# Out:
# 14

# %%
pd.read_sql("SELECT * FROM SALARY", conn)
# Out:
#                  title gender  MIN(salary)  AVG(salary)  MAX(salary)  \
# 0   Assistant Engineer      M        39827   57197.9674       117636
# 1   Assistant Engineer      F        39469   57495.9861       106340
# 2             Engineer      M        38942   59592.9683       130939
# 3             Engineer      F        39519   59617.3549       115444
# 4              Manager      M        56654   79350.6000       106491
# 5              Manager      F        65400   75690.0000        83457
# 6      Senior Engineer      M        39285   70869.9085       140784
# 7      Senior Engineer      F        39476   70753.8341       138273
# 8         Senior Staff      M        39012   80735.4795       158220
# 9         Senior Staff      F        39227   80662.9816       152710
# 10               Staff      M        39186   67362.1754       133577
# 11               Staff      F        38936   67282.4599       137875
# 12    Technique Leader      M        38623   67599.6710       132233
# 13    Technique Leader      F        39812   67369.0734       144434
#
#     COUNT(salary)
# 0            2148
# 1            1440
# 2           18571
# 3           12412
# 4               5
# 5               4
# 6           51533
# 7           34406
# 8           49232
# 9           32792
# 10          15436
# 11          10090
# 12           7189
# 13           4866

# %%
pd.read_sql('SELECT name FROM sqlite_master WHERE type="table"', conn)
# Out:
#      name
# 0  SCHOOL
# 1  SALARY

# %% [markdown]
# En ocasiones necesitamos crear vistas

# %%
cursor.execute('''
CREATE VIEW INGENIEROS AS
SELECT * FROM SALARY
WHERE title = 'Engineer'
''')
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20304\2907458983.py in <module>
# ----> 1 cursor.execute('''
#       2 CREATE VIEW INGENIEROS AS
#       3 SELECT * FROM SALARY
#       4 WHERE title = 'Engineer'
#       5 ''')
#
# OperationalError: view INGENIEROS already exists

# %%
pd.read_sql('SELECT * FROM INGENIEROS', conn)
# Out:
#       title gender  MIN(salary)  AVG(salary)  MAX(salary)  COUNT(salary)
# 0  Engineer      M        38942   59592.9683       130939          18571
# 1  Engineer      F        39519   59617.3549       115444          12412

# %% [markdown]
# Para borrar tablas usamos el comando `DROP TABLE`

# %%
# Borrar tablas

cursor.execute('DROP TABLE IF EXISTS SALARY')

# %%
# Listar tablas
pd.read_sql('SELECT name FROM sqlite_master WHERE type="table"', conn)
# Out:
#    ID   NAME  AGE       CITY  MARKS
# 0   1   Luis   24     Madrid      8
# 1   3  Pedro   19  Santander      7

# %% [markdown]
# Para actualizar registros usamos el comando `UPDATE`

# %%
# Actualizar registros
conn.execute('UPDATE SCHOOL SET MARKS=7 WHERE ID=3')
conn.commit()

# %%
pd.read_sql('SELECT * FROM SCHOOL', conn)

# %% [markdown]
# Si queremos borrar registros usamos `DELETE`

# %%
conn.execute('DELETE FROM SCHOOL WHERE ID=2')
conn.commit()

# %%
pd.read_sql('SELECT * FROM SCHOOL', conn)

# %% [markdown]
# Existen aplicaciones gratuitas, como [DB Browser for SQLite](https://sqlitebrowser.org/) que nos operar con bases de datos SQL desde una interfaz

# %% [markdown]
# <a id="nosql"></a>
# ## Material Extra: Bases de datos NoSQL (MongoDB)

# %% [markdown]
# Las principales diferencias entre SQL y MongoDB son las siguientes:
# <img src='http://4.bp.blogspot.com/-edz2_QrFvCE/UnzBhKZE3FI/AAAAAAAAAEs/bTEsqnZFTXw/s1600/SQL-MongoDB+Correspondence.PNG'>

# %% [markdown]
# Vamos a conectarnos a una base de datos en MongoDB, para lo cual debemos instalar las siguientes librerías:
# `conda install -c anaconda pymongo`
# `conda install -c anaconda dnspython`

# %%
from pymongo import MongoClient
import dns

# %%
client = MongoClient("mongodb+srv://rzl:rzl@cluster0.a0ju2.mongodb.net/?retryWrites=true&w=majority")

# %% [markdown]
# Nos conectamos a la base de datos [Sample Airbnb](https://docs.atlas.mongodb.com/sample-data/sample-airbnb/). Esta base de datos contiene una única colección llamada listingsAndReviews, que contiene documentos representando detalles de viviendas turísticas en airbnb.

# %%
db = client.get_database('sample_airbnb')

# %%
records = db.listingsAndReviews

# %%
# Contamos los documentos
records.count_documents({})
# Out:
# 5555

# %% [markdown]
# Para hacer queries se utiliza el método `find()`

# %%
list(records.find())[0]
# Out:
# {'_id': '1001265',
#  'listing_url': 'https://www.airbnb.com/rooms/1001265',
#  'name': 'Ocean View Waikiki Marina w/prkg',
#  'summary': "A short distance from Honolulu's billion dollar mall, and the same distance to Waikiki. Parking included. A great location that work perfectly for business, education, or simple visit. Experience Yacht Harbor views and 5 Star Hilton Hawaiian Village.",
#  'space': 'Great studio located on Ala Moana across the street from Yacht Harbor and near Ala Moana Shopping Center. Studio kitchette, parking, wifi, TV, A/C. Amenities include pool, hot tub and tennis. Sweet ocean views with nice ocean breezes.',
#  'description': "A short distance from Honolulu's billion dollar mall, and the same distance to Waikiki. Parking included. A great location that work perfectly for business, education, or simple visit. Experience Yacht Harbor views and 5 Star Hilton Hawaiian Village. Great studio located on Ala Moana across the street from Yacht Harbor and near Ala Moana Shopping Center. Studio kitchette, parking, wifi, TV, A/C. Amenities include pool, hot tub and tennis. Sweet ocean views with nice ocean breezes. Pool, hot tub and tennis We try our best at creating, simple responsive management which never bothers the guest. You can breath ocean as well as aloha. Honolulu does have a very good air conditioned bus system.",
#  'neighborhood_overview': 'You can breath ocean as well as aloha.',
#  'notes': '',
#  'transit': 'Honolulu does have a very good air conditioned bus system.',
#  'access': 'Pool, hot tub and tennis',
#  'interaction': 'We try our best at creating, simple responsive management which never bothers the guest.',
#  'house_rules': 'The general welfare and well being of all the community.',
#  'property_type': 'Condominium',
#  'room_type': 'Entire home/apt',
#  'bed_type': 'Real Bed',
#  'minimum_nights': '3',
#  'maximum_nights': '365',
#  'cancellation_policy': 'strict_14_with_grace_period',
#  'last_scraped': datetime.datetime(2019, 3, 6, 5, 0),
#  'calendar_last_scraped': datetime.datetime(2019, 3, 6, 5, 0),
#  'first_review': datetime.datetime(2013, 5, 24, 4, 0),
#  'last_review': datetime.datetime(2019, 2, 7, 5, 0),
#  'accommodates': 2,
#  'bedrooms': 1,
#  'beds': 1,
#  'number_of_reviews': 96,
#  'bathrooms': Decimal128('1.0'),
#  'amenities': ['TV',
#   'Cable TV',
#   'Wifi',
#   'Air conditioning',
#   'Pool',
#   'Kitchen',
#   'Free parking on premises',
#   'Elevator',
#   'Hot tub',
#   'Washer',
#   'Dryer',
#   'Essentials',
#   'Shampoo',
#   'Hangers',
#   'Hair dryer',
#   'Iron',
#   'Laptop friendly workspace',
#   'Self check-in',
#   'Lockbox',
#   'Hot water',
#   'Bed linens',
#   'Extra pillows and blankets',
#   'Ethernet connection',
#   'Microwave',
#   'Coffee maker',
#   'Refrigerator',
#   'Dishes and silverware',
#   'Cooking basics',
#   'Stove',
#   'BBQ grill',
#   'Garden or backyard',
#   'Well-lit path to entrance',
#   'Disabled parking spot',
#   'Step-free access',
#   'Wide clearance to bed',
#   'Step-free access'],
#  'price': Decimal128('115.00'),
#  'weekly_price': Decimal128('650.00'),
#  'monthly_price': Decimal128('2150.00'),
#  'cleaning_fee': Decimal128('100.00'),
#  'extra_people': Decimal128('0.00'),
#  'guests_included': Decimal128('1'),
#  'images': {'thumbnail_url': '',
#   'medium_url': '',
#   'picture_url': 'https://a0.muscache.com/im/pictures/15037101/5aff14a7_original.jpg?aki_policy=large',
#   'xl_picture_url': ''},
#  'host': {'host_id': '5448114',
#   'host_url': 'https://www.airbnb.com/users/show/5448114',
#   'host_name': 'David',
#   'host_location': 'Honolulu, Hawaii, United States',
#   'host_about': 'I have 30 years of experience in the Waikiki Real Estate Market. We specialize in local sales and property management. Our goal is service and aloha. We want to help people enjoy Hawaii.',
#   'host_response_time': 'within an hour',
#   'host_thumbnail_url': 'https://a0.muscache.com/im/users/5448114/profile_pic/1363202219/original.jpg?aki_policy=profile_small',
#   'host_picture_url': 'https://a0.muscache.com/im/users/5448114/profile_pic/1363202219/original.jpg?aki_policy=profile_x_medium',
#   'host_neighbourhood': 'Waikiki',
#   'host_response_rate': 98,
#   'host_is_superhost': False,
#   'host_has_profile_pic': True,
#   'host_identity_verified': False,
#   'host_listings_count': 18,
#   'host_total_listings_count': 18,
#   'host_verifications': ['email', 'phone', 'reviews', 'kba']},
#  'address': {'street': 'Honolulu, HI, United States',
#   'suburb': 'Oʻahu',
#   'government_area': 'Primary Urban Center',
#   'market': 'Oahu',
#   'country': 'United States',
#   'country_code': 'US',
#   'location': {'type': 'Point',
#    'coordinates': [-157.83919, 21.28634],
#    'is_location_exact': True}},
#  'availability': {'availability_30': 16,
#   'availability_60': 46,
#   'availability_90': 76,
#   'availability_365': 343},
#  'review_scores': {'review_scores_accuracy': 9,
#   'review_scores_cleanliness': 8,
#   'review_scores_checkin': 9,
#   'review_scores_communication': 9,
#   'review_scores_location': 10,
#   'review_scores_value': 9,
#   'review_scores_rating': 84},
#  'reviews': [{'_id': '4765259',
#    'date': datetime.datetime(2013, 5, 24, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '6435238',
#    'reviewer_name': 'Jacqui',
#    'comments': "Our stay was excellent.  The place had a breath taking view.  David was very accommodating with our hotel stay, parking availability and all of our concerns & questions.  He did above and beyond what anyone would want.  He's a man of his word and very professional.  We highly recommend for everyone to stay in all of the places he recommended.  Thank you David for a accommodating our wonderful and memorable stay in Honolulu, Hawaii.  God Bless!  Henry & Jacqui (SF, CA)"},
#   {'_id': '4908312',
#    'date': datetime.datetime(2013, 6, 1, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '3454262',
#    'reviewer_name': 'Khoren',
#    'comments': 'Tell others in the Airbnb community about your stay.'},
#   {'_id': '7099260',
#    'date': datetime.datetime(2013, 9, 6, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '7038567',
#    'reviewer_name': 'Nick',
#    'comments': "This is everything we expected and hoped for in a sub-$100/night condo stay in Waikiki. This definitely isn't the Ritz, and if you're looking for a luxury get-away, you're barking up the wrong tree. However, if you're like we were: first time visitors on a budget with humble taste, then this place is perfect. The location is a tiny bit removed from the touristy Beachwalk shopping area, but not so far as to preclude you from limbering up for a spirited walk over there. And by the marina, you're actually quite close to the Ala Moana mall. So, the location is good. The place itself is a modest studio setup, but perfectly adequate with a good sized bed for a couple, enough space for your luggage, and a kitchenette and bathroom that though tight, is perfectly fine. There's also cable and internet if you're looking for homey creature comforts. It was also fantastic to have a free parking space included, an air conditioning wall unit, and the panoramic window view was pretty cool, though you only really get a peak of the beach. Also, David was very good about staying in contact with us the day we arrived to get acclimated, and we did not have further occasion to require his services the rest of our stay, so our contact was minimal, but satisfactory ... no problem there. The minor quibbles we had were pretty thin walls, so we would often hear the murmur of the neighbors' TVs. Also, there seemed to be two elevators working the entire building, so they could take quite a while to pop up. Again though, if you're like us, your #1 priorities are spend a minimal amount of time in your room, get out to experience Hawaii, come back to a sanitary place to sleep at night, all while staying within a reasonable budget. This place fit the bill, and we would recommend it to anyone with the same priorities."},
#   {'_id': '8363944',
#    'date': datetime.datetime(2013, 10, 28, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '7096845',
#    'reviewer_name': 'Jean',
#    'comments': 'Fantastic location! Everything in the condo was great and David was lovely and super easy to deal with. Would recommend!'},
#   {'_id': '8905060',
#    'date': datetime.datetime(2013, 11, 25, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '9432081',
#    'reviewer_name': 'Dhaval',
#    'comments': 'The flat is ok for a couple . Location of flat is awesome. Its close to the waikiki beach, Ala Moana park and shoppings . Parking was 20 bucks/day . Overall nice place.'},
#   {'_id': '9392425',
#    'date': datetime.datetime(2013, 12, 26, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '9009226',
#    'reviewer_name': 'Carol E',
#    'comments': 'We stayed 23 days in December in "Ocean view Waikiki Marina". Our stay was great, the apartment is very well located, clean and comfortable. David and Nicole were very attentive and helped us at all. Loved our vacation in Hawaii and want to return soon. \r\n\r\nAloha!'},
#   {'_id': '9496168',
#    'date': datetime.datetime(2013, 12, 31, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '6184569',
#    'reviewer_name': 'Sophie & Lo',
#    'comments': "If you're looking to spend most of your time in Hawaii outside (and not inside your room or your hotel, like with the Waikiki resort complexes) then this apartment will do the trick. It's definitely not luxurious but has the basics and is in a great location. It fits 2 people but more would be cramped. \nYou can hit the beach in as little as 5 mns walking or get to central Waikiki beach in 15-20 mns walking.  It's also easy to catch a bus to visit something outside Waikiki. There is a convenience store nearby, as well as several breakfast and restaurant options. The apartment has a small kitchen with cooking utensils but we ended up mostly eating dinners out. \nDavid was courteous and likely very knowledgeable about the area but we didn't ask him for suggestions, we ended up just using our guide book. \nOverall if you want to experience Waikiki without spending a fortune or being pampered, this is a great option. Mahalo David!"},
#   {'_id': '9770517',
#    'date': datetime.datetime(2014, 1, 9, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '2903621',
#    'reviewer_name': 'Tj',
#    'comments': 'Great location, adequate for a short stay, free parking too!'},
#   {'_id': '10423465',
#    'date': datetime.datetime(2014, 2, 18, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '11043919',
#    'reviewer_name': 'Rose',
#    'comments': 'David was there to meet us as soon as we arrived from the airport and was very friendly. He communicated with us before we arrived as well. The apartment was very nice, great location, clean and exactly what we were looking for. Location has a nice pool area.'},
#   {'_id': '10956151',
#    'date': datetime.datetime(2014, 3, 15, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '11421452',
#    'reviewer_name': 'Susan',
#    'comments': "Thoroughly enjoyed our stay. The condo is in a great location if you want to be in or near Waikiki and Ala Moana. It's a small studio, and not luxurious, but great if you want a functional, reasonably comfortable and very affordable base for exploring Oahu. The parking space is wonderful if you rent a car, as otherwise you're looking at an additional $15-$20 a day. The building is right on Ala Moana Blvd so it's noisy if you keep the windows open, but that's also true of many high-price Waikiki hotel rooms. Air conditioning is a bit noisy; I slept with earplugs but my boyfriend didn't need them (I'm a light sleeper and use them at home). The condo has a full size fridge, small cooktop, microwave, coffee maker, coffee press, beach chairs, some knackered beach mats, towels, pots, plates, etc.. Wifi is a plus. The bathroom appears quite recently updated, and though small is nice - great shower. \r\n\r\nCons: There's no lanai and the view is very partial, but to us those were small things. Elevators were sometimes very slow and occasionally out of commission, which was a hassle and a bit concerning.\r\n\r\nWe never actually met David. All was handled by text and email. He instructed us to get someone to let us in to the building, which seemed a bit dodgy, but in the end it was no problem, and he said to call if there was any issue. Condo door was unlocked and keys were on the table.\r\n\r\nI would consider staying here again if I plan to stay in the Waikiki vicinity. \r\n\r\n"},
#   {'_id': '11063672',
#    'date': datetime.datetime(2014, 3, 18, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '12932701',
#    'reviewer_name': 'Tami',
#    'comments': "If you are looking for a home base with the basics to lay your head at night and have breakfast in and then head out for the day this fits the bill. It's close to Waikiki and the downtown area but not in the thick of things so if you're looking to avoid the 24/7 hustle and bustle then this might work for you. There is a basic kitchenette and eating area. Accessories for enjoying the sand and surf are available for use, pool, and hot tub as well, and secure parking which is a plus.\r\n\r\nIf you're looking for expansive ocean views, a room to hang out and relax in with up to date decor, and where you can easily meet and get to know people staying in the complex then this wouldn't be for you. The dependability of the elevators, particularly during high winds, is a bit of a concern.\r\n\r\nI never met David, things were handled via airbnb email. I spoke with him on the phone when my plans changed and he was flexible in changing the dates of the original reservation.\r\n"},
#   {'_id': '11326297',
#    'date': datetime.datetime(2014, 3, 30, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '5394313',
#    'reviewer_name': 'Christopher',
#    'comments': "Our stay here was great and just as we expected!  The apartment was in a really fantastic location and was very convenient.  It is a small, simple, and nice apartment with a cool view.  As a bonus, we talked with some other people that lived there that gave us great pointers about what to do during our stay there.  The included parking was also extremely convenient!  Check in and check out was simple, David's communication was outstanding, and he was very accommodating.  I would not hesitate to stay here again."},
#   {'_id': '13172738',
#    'date': datetime.datetime(2014, 5, 21, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '4227123',
#    'reviewer_name': 'Robert',
#    'comments': 'The reservation was canceled 21 days before arrival. This is an automated posting.'},
#   {'_id': '13305026',
#    'date': datetime.datetime(2014, 5, 25, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '5969944',
#    'reviewer_name': 'Christian',
#    'comments': 'Great location close to Waikiki beach. The apartment was clean and nice and simple, me and my wife would definitely consider staying here again.\r\nParking in the building was great for us as we where moving around the island a lot.\r\n\r\nWould definitely recommend!\r\n\r\nAloha!'},
#   {'_id': '13853905',
#    'date': datetime.datetime(2014, 6, 6, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '5762133',
#    'reviewer_name': 'Jessica And Ryan',
#    'comments': 'Excellent.  No Resort Fee.  No Parking Fee.  No Internet fee.  Kitchenette.  Walk to everything.'},
#   {'_id': '15400986',
#    'date': datetime.datetime(2014, 7, 8, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '14207377',
#    'reviewer_name': 'Shawn',
#    'comments': 'Great little unit, close to beach, shopping and restaurants with laundry machines on lower floors. Air conditioning was a nice treat, as was wifi and a parking spot in a secure garage. We chilled out for a day in the unit just watching tv.  The local coffee house next to the IHOP was well worth the wait. David was helpful and responsive to inquiries. '},
#   {'_id': '15837412',
#    'date': datetime.datetime(2014, 7, 16, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '17333518',
#    'reviewer_name': 'Eric',
#    'comments': 'We were really pleased staying at the Waikiki Marina.  The unit is in a great location and has all of the comforts to make staying there a pleasure.  Everything was clean and well maintained and we appreciated the solid wifi access as I had to work part of the time we stayed here.  I would definitely recommend this comfortable unit to anyone wanting a more private and more affordable Waikiki experience!'},
#   {'_id': '16132741',
#    'date': datetime.datetime(2014, 7, 22, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '9594791',
#    'reviewer_name': 'Sebastiana',
#    'comments': 'Nice unit! Not fancy but perfect!\nComfortable and quiet. I did use \nthe unit as a home base and I was very happy to be able to cook my meals there.\nVery good location! Right next to the Ala Moana shopping center.\nDavid was very helpful and accommodating and a gracious host!\nI would stay again, and recommend! '},
#   {'_id': '16977781',
#    'date': datetime.datetime(2014, 8, 5, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '15286830',
#    'reviewer_name': 'Jenell',
#    'comments': 'Great location, close to everything. I really appreciated the parking space! Great response from David, wonderful experience. Very basic place but had everything I needed. Thanks!'},
#   {'_id': '18260191',
#    'date': datetime.datetime(2014, 8, 24, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '7992631',
#    'reviewer_name': 'Jason',
#    'comments': 'The apartment is very centrally located and we had a great time walking around. The parking also helped and allowed us to drive anywhere we wanted.'},
#   {'_id': '18985212',
#    'date': datetime.datetime(2014, 9, 4, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '10853111',
#    'reviewer_name': 'Katharine',
#    'comments': "This unit was as pictured - practical and fit the bill for what we required: bed, kitchenette and a good wifi connection. The secure parking, cable tv and air conditioning unit were a bonus, as was the view! The unit was in a prime location, close to Waikiki and Ala Moana, and really convenient to locate. David was easy to reach and the check-in / check-out process was easy. The unit is also close to major highways so it is easy to get on/off hwy 1. \r\n\r\nBoth elevators were down at one point during our stay, but it wasn't a problem - walking up/down was easy (we didn't have anything to carry) and one elevator was fixed by the time we got back in the evening. \r\n\r\nDavid, thank you for the stay - it was great! "},
#   {'_id': '19131965',
#    'date': datetime.datetime(2014, 9, 7, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '11952818',
#    'reviewer_name': 'Mike',
#    'comments': "David was extremely communicative throughout the entire process. Getting into the room was very simple and parking was a huge plus. The location of the unit is perfect - walking distance from all the Wakiki beaches, restaurants, shops, and ABC stores. \r\n\r\nThe unit itself was a bit run-down. The cabinets and doors felt like they needed an update and the bed wasn't the most comfortable. The elevator in the building (our unit was on the 16th floor) was painfully slow but that's no fault of David's. \r\n\r\nAll in all, this was a great move over a hotel or something and the price is great."},
#   {'_id': '20956267',
#    'date': datetime.datetime(2014, 10, 8, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '20026889',
#    'reviewer_name': 'Kai',
#    'comments': 'The location was fantastic.  David is very responsive if you have any questions and is accommodating when you have special requests.  We arrived a day early due to unforeseen circumstances but we were able to check in a day early and also we were able to leave our luggage on the last day for a few extra hours.'},
#   {'_id': '23490671',
#    'date': datetime.datetime(2014, 12, 2, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '7289452',
#    'reviewer_name': 'Wendy',
#    'comments': "We enjoyed our stay at David's place in Waikiki. The apartment is small but clean. Amenities are basic. The kitchen and the bathroom could use some updates, but everything is functional. Wifi worked perfectly, so no complaint on connectivity. Checking in was very easy. We followed the instruction to get the key and found our parking spot without any problem. The location of the apartment is also very convenient. A few blocks to the beach and choices of restaurants near by. There are less tourists in this part of the town, so it's more quite and less crowded"},
#   {'_id': '23593371',
#    'date': datetime.datetime(2014, 12, 6, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '1621775',
#    'reviewer_name': 'Silke',
#    'comments': 'We had a pleasant stay. Location was super. Only 10 minute walk to waikiki beach and short drive to alamoena mall.'},
#   {'_id': '25433210',
#    'date': datetime.datetime(2015, 1, 16, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '4359615',
#    'reviewer_name': 'James',
#    'comments': "Staying at David's apartment was quite a pleasurable experience.  He was very responsive when scheduling the apartment.  Access was incredibly easy as he left the keys in a lock box near the private parking.  Unit was clean, great views of the marina and in the heart of Waikiki.  All of this for under $110/night, I couldn't have asked for more.  If ever back in Oahu, I'll be sure to reach out to David again."},
#   {'_id': '26470420',
#    'date': datetime.datetime(2015, 2, 13, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '26499737',
#    'reviewer_name': 'Matthew',
#    'comments': 'Smooth check in/out.  Great building.'},
#   {'_id': '26905009',
#    'date': datetime.datetime(2015, 2, 22, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '10169533',
#    'reviewer_name': 'Carolyn',
#    'comments': "First, I would like to say that while I only met David briefly once, he was always available and responded to messages/questions immediately and was happy to give ideas and suggestions for places to visit. The unit was as described with all the basic amenities one would need. I couldn't have asked for a better location as you could easily walk to the mall and the park as well as catch the bus for getting around the island. I would happily stay here again should my travels take me back to Honolulu."},
#   {'_id': '27136069',
#    'date': datetime.datetime(2015, 2, 26, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '26427652',
#    'reviewer_name': 'Gina',
#    'comments': "Very easy to communicate with David in regards to the logistics of checking in, checking out, the lockbox instructions etc. Apartment location was convenient to Waikiki. Included parking was also great. \nThe actual unit itself was very worn out and although I'm sure it was cleaned, it didn't feel too clean because of the amount of wear and tear. \nBut for the price and location, it couldn't be beat!"},
#   {'_id': '27507360',
#    'date': datetime.datetime(2015, 3, 6, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '27664697',
#    'reviewer_name': 'Dan',
#    'comments': 'Had a great stay.  Felt a lot like a hotel room, which was fine as we had plenty to do out on the town. Great location, David was friendly, helpful and responsive,as were the building security guards.'},
#   {'_id': '27760285',
#    'date': datetime.datetime(2015, 3, 11, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '2360598',
#    'reviewer_name': 'Julia',
#    'comments': "The location could not be beat, and such a great price.  Super convenient, parking included, walking distance to plenty of shops, restaurants, bars, and the beach.   The unit is a little dated, but it's clean and comfortable.  David's instructions were clear and easy on getting into the unit and finding the parking.  The elevators are a bit slow and one of them was always down for service, but that's no fault of Davids, just a warning if you are in impatient person.  If you are looking for an affordable place in a very good location check this place out.  "},
#   {'_id': '29296049',
#    'date': datetime.datetime(2015, 4, 6, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '28683824',
#    'reviewer_name': 'Warren',
#    'comments': "Location, location, location.  As a former 5-year resident of Honolulu I can attest that this building is conveniently located at the entrance of Waikiki close to the Ala Moana Shopping Center and Ala Moana Beach.  This was my very first experience ever using Airbnb so I didn't really know what to expect.  I travel to Honolulu 4 times a year and always stay in a hotel, but my cousin recommended I try Airbnb as a less expensive alternative.  I had some technical issues when I first checked into the studio getting the window A/C unit (A/C remote I believe had dead batteries) and cable TV to work (T/V HDMI input wrong) but with David conveniently living in the building, he was quick to remedy the situation.  "},
#   {'_id': '30307467',
#    'date': datetime.datetime(2015, 4, 20, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '29163178',
#    'reviewer_name': 'Paula',
#    'comments': 'The unit is older and in need of a facelift but it’s got the basics, including a full size fridge, and best of all includes a free designated parking space.  Parking is difficult to come by in Waikiki and when available will run you at least $25 a day so this condo is a bargain.  Lockbox made for easy check-in/check-out.  Elevators in this tower are iffy but at least one of the two elevators was working during our stay so not a problem.  David was great and yes, the next time we need to visit Waikiki, we’ll book the apt. again.'},
#   {'_id': '32681422',
#    'date': datetime.datetime(2015, 5, 20, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '28796283',
#    'reviewer_name': 'Herve',
#    'comments': 'Thank you for the Location, the parking space , the Wifi and TV . The communication was either by phone or email and was prompt. It was 5 mins from Ala Moana shopping centre and  5 mins from the beach. it was easy to walk to the Main Waikiki beach even at night. Bus 20 or the trolley was easy to access from the main road and a lot of eating places nearby. The weather was a nice 27 deg with a few showers from time to time and the Circle Island tour from Roberts or  any other tour guide was around $35  and  was worth the price. '},
#   {'_id': '33675716',
#    'date': datetime.datetime(2015, 5, 31, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '5265153',
#    'reviewer_name': 'Debbie',
#    'comments': "This was the perfect location for my trip.  It had everything I needed. The A/C was a little questionable, but the large window worked great. You can't be the price or the location.  Great stay.  "},
#   {'_id': '34556306',
#    'date': datetime.datetime(2015, 6, 9, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '33323993',
#    'reviewer_name': 'Lawron',
#    'comments': 'The quick communication and easy access to this unit made our stay a breeze, David is lovely and always available to contact if needed. The description and images of the unit are 100% accurate - location is prime! The inclusion of a carpark means we could hire a bike/car and explore the island! Minutes walk to shopping, beach and restaurants. Had an amazing stay, will definitely be back!'},
#   {'_id': '34792224',
#    'date': datetime.datetime(2015, 6, 12, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '6108612',
#    'reviewer_name': 'Tuguy',
#    'comments': 'Perfect location , everything is a walking distance(beach, shops bus stops.etc). The unit is outdated but it does the job and everything works great. i have no complains me and my gf liked it and the price was right.'},
#   {'_id': '35546261',
#    'date': datetime.datetime(2015, 6, 20, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '6869553',
#    'reviewer_name': 'Matthew',
#    'comments': 'Overall a good experience. David was prompt and businesslike with communication. The apartment is in a good location, close to the convention center and Waikiki. The apartment is basic.'},
#   {'_id': '37843504',
#    'date': datetime.datetime(2015, 7, 11, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '5432240',
#    'reviewer_name': 'Alizée',
#    'comments': "Nous avons passé une semaine très agréable dans le logement de David. Le check-in est simple et efficace, l'emplacement est très bon (on peut aller à Waikiki à pied sans problème, mais on évite ici le bruit et l'agitation du quartier) et la taille de l'appartement tout à fait satisfaisante pour deux personnes. On oublie rapidement le côté un peu vétuste de l'immeuble et le bruit de la clim (qui fonctionne très bien pour refroidir la chambre cela dit) en appréciant :\r\n- La propreté du logement\r\n- La vue sur le port et l'océan \r\n- Tout est fonctionnel, et il y a même quelques objets utiles en plus comme une glacière souple que nous avons pu utiliser pour la plage\r\n- La piscine et le jacuzzi\r\n- La place de parking réservée pour nous\r\n- La rapidité de David pour répondre à nos questions\r\n- La petite supérette ABC store juste au coin de la rue qui dépanne bien en cas de besoin.\r\n\r\nSi nous avons la chance de revenir un jour à Hawaï, ce pourrait être dans ce même logement avec plaisir !\r\n\r\nMahalo :) "},
#   {'_id': '38303028',
#    'date': datetime.datetime(2015, 7, 14, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '36012911',
#    'reviewer_name': 'Garret',
#    'comments': 'Super easy check in and convenient location. Was as advertised. Would definitely stay here again.'},
#   {'_id': '40390482',
#    'date': datetime.datetime(2015, 7, 30, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '36673068',
#    'reviewer_name': 'Alyssa',
#    'comments': "The room was beautiful and the location was awesome. There was a lot to do in the area and you definitely get your money's worth and some! I loved it, it was fun and relaxing!"},
#   {'_id': '40991480',
#    'date': datetime.datetime(2015, 8, 3, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '35955759',
#    'reviewer_name': 'None',
#    'comments': 'Great location. Awesome view. The room is a bit older. David was clear and prompt with his communications.'},
#   {'_id': '42667108',
#    'date': datetime.datetime(2015, 8, 15, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '522473',
#    'reviewer_name': 'Helene',
#    'comments': "The place was great, even nicer than it appears on the pictures. The kitchen is well supplied with all the necessary appliances and dishes. The bedroom is large and comfortable. The location was ideal for my purpose. \r\nCheck in and out was a breeze. I'd come back again!"},
#   {'_id': '43293928',
#    'date': datetime.datetime(2015, 8, 18, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '27273789',
#    'reviewer_name': 'Pong',
#    'comments': 'David is a very kind and helpful person, he helped us to call taxi, the room is at good location, walk to beach, walk to shopping mall, more cheaper than other hotels like hoilton or hyatt*-:-)'},
#   {'_id': '45347142',
#    'date': datetime.datetime(2015, 9, 1, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '7786809',
#    'reviewer_name': 'Ross',
#    'comments': 'Got what we paid for. Very basic room, great location just a walk from the beach. Although the place looked older it was still very clean. The climate control was really nice. Directions were very clear. Good stay.'},
#   {'_id': '45555971',
#    'date': datetime.datetime(2015, 9, 4, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '4447381',
#    'reviewer_name': 'Mike',
#    'comments': 'Great convenient location\r\nDavid was extremely helpful and always available - a real gentleman!\r\nAccomodation was practical and functional\r\nHighly recommended!'},
#   {'_id': '47266766',
#    'date': datetime.datetime(2015, 9, 17, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '11899853',
#    'reviewer_name': 'Liza',
#    'comments': "Overall experience was great! The apartment room was a good size for my husband and I. The bed was comfortable, the room was clean, and David was kind enough to provide the little necessities and supplies we needed to enjoy our trip.  Location can't be beat! Whether you've got a car, plan to walk, or use public transport, the building was right in the middle of the hustle and bustle. We found the ABC store just beside the building very useful. The AC worked perfectly! Kept us cool and comfortable. \n\nDealing with David was a pleasure. He remained in close communication with us. Met him once, asked us how we were doing, and was very pleasant.\n\nFor the price and the location, this is a great room!"},
#   {'_id': '48673332',
#    'date': datetime.datetime(2015, 9, 28, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '25553952',
#    'reviewer_name': 'Sara',
#    'comments': "This condo is in a great location, very close to lots of restaurants, shopping and beaches. It's small but clean. The only down side was one of the elevators was broken but we were on vacation so we weren't in a rush. David was very helpful with all instructions.\n\nMahalo, David"},
#   {'_id': '51287788',
#    'date': datetime.datetime(2015, 10, 19, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '13006995',
#    'reviewer_name': 'James',
#    'comments': 'Great location within a short walk to Waikiki hotspots and the Ala Moana mall.  The apartment was clean and comfortable.  The only downside of the building was that one of the two elevators was under maintenance during my stay, so getting up and down from the apartment to the ground floor took a little while.  But, aside from that one little annoyance, this was a really nice place to stay for a week.  David was very prompt in responding to all of my communications, and had everything ready for me when I arrived.'},
#   {'_id': '51894139',
#    'date': datetime.datetime(2015, 10, 25, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '40727289',
#    'reviewer_name': 'Susan',
#    'comments': 'Waikiki Marina is in a convenient location. It does however need some sprucing up including new bed sheets and towels. It has a lot of potential for being a lovely apartment. David was very accommodating in helping us store our luggage before check in time which was very helpful.'},
#   {'_id': '52582553',
#    'date': datetime.datetime(2015, 10, 31, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '5928829',
#    'reviewer_name': 'Larry',
#    'comments': "The location is great, particularly if you are going to the Convention center or Waikiki.  \n\nOnly challenge was the elevators. It's a 40 story building with 2 elevators.  One had apparently been out of service for a couple of weeks and then the other stopped working.  After a few climbs to the 16th floor at least one was back in service.  Both David and AirBNB were very attentive and I got a partial refund for that day.  \n\nThere is shopping nearby.  Cleanliness was good.  David lives next door and so can be there quickly if needed. "},
#   {'_id': '53135972',
#    'date': datetime.datetime(2015, 11, 5, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '47026022',
#    'reviewer_name': 'Daniel',
#    'comments': "Place was as advertised, clean and tidy, only 5 minutes away from waikiki beach and the Ala Moa shopping centre. Can't beat the price especially with parking included in waikiki! fresh towels and beach utilities were provided.  100% recommended!"},
#   {'_id': '54378233',
#    'date': datetime.datetime(2015, 11, 19, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '45476928',
#    'reviewer_name': 'Connie',
#    'comments': "We never did meet David in person, but communicated by email and text.  His directions for getting the keys to the condo were easy to follow and we had no trouble.  The room was comfortable and clean but could use some new drapes and carpet. Our only complaint was beyond David's control--only one elevator in the building was working so getting up and down was very slow."},
#   {'_id': '56182071',
#    'date': datetime.datetime(2015, 12, 10, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '12403444',
#    'reviewer_name': 'Laura',
#    'comments': 'A great apartment at a very convenient and quiet location yet walking distance to shopping mall and to Waikiki.  Parking is included which is not so common for most listing. \n\nApartment is simple and cosy. All basic necessities are provided. Feels like home right away. We got lucky with the elevators (unlike most reviews) as both elevators were operating during most part of our stay. \n\nWe had a bathroom crisis in the middle of the night when the flushing tank overflowed and almost flooded. Luckily David took care of it right away in the morning and even cleaned up the affected. \n\n'},
#   {'_id': '57005229',
#    'date': datetime.datetime(2015, 12, 21, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '22221603',
#    'reviewer_name': 'Todd',
#    'comments': 'David was easy to communicate with.  The location of the apartment is excellent with regard to Waikiki and the Convention Centre.  Only negative is the rather poor elevator support.  Only one was functioning at the time I was there. Made getting up and down slow.'},
#   {'_id': '57628226',
#    'date': datetime.datetime(2015, 12, 28, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '8745141',
#    'reviewer_name': 'Cerys',
#    'comments': 'The condo is well located and the check in process was really easy. David always answered my emails really quickly, which was helpful given the fluid nature of my plans. Mahalo.'},
#   {'_id': '59111317',
#    'date': datetime.datetime(2016, 1, 7, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '37485444',
#    'reviewer_name': 'Stephanie',
#    'comments': "Easy to schedule, instructions for finding the key were simple to follow, parking garage remote was easy to operate, and everything worked out well. Spent 9 days on Oahu to attend a conference and visit family. If you're looking for a no frills, small but clean place to stay where you can save a few $$ by cooking and warming local meals easily in the mini kitchen and walking to the Hilton Hawaiian Village (.8 mi.) this is the place for you. Elevator was a bit slow so if you have to be somewhere on time you'll need to allow maybe 10-15 additional min. A/C worked but slow upon startup but who cares if you're enjoying the outdoors and rarely in the room? Ran into David in the lobby just before checking out--he is kind and lovely! Would stay here again."},
#   {'_id': '59991234',
#    'date': datetime.datetime(2016, 1, 18, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '1479377',
#    'reviewer_name': 'Mark',
#    'comments': "The condo was a great deal, centrally located by shops and restaurants in the Ala Moana district. Comfortable bed, AC, a nice shower and plenty of clean towels. Also the parking spot was a huge plus. David's directions were clear and accurate and he was very responsive to my questions. I would definitely come back."},
#   {'_id': '61152426',
#    'date': datetime.datetime(2016, 2, 1, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '3561883',
#    'reviewer_name': 'Annie',
#    'comments': 'Le studio est propre et bien situé. Les explications de David pour les clés et le parking étaient très utiles. Les couchers de soleil sont magnifiques du studio! On a aussi profité des serviettes de plages et du parasol qui étaient à notre disposition. Le seul hic? Les ascenseurs! Sur 4 nuits, on s eu une seule journée où les deux fonctionnaient alors il fallait attendre entre 10-15 minutes chaque fois ... '},
#   {'_id': '62695425',
#    'date': datetime.datetime(2016, 2, 16, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '12849759',
#    'reviewer_name': 'Sean',
#    'comments': "David was great, and the apartment was spacious, clean, and well-priced. I give it three stars only because of the problems with the elevator. The one working elevator was broken half the time and incredibly slow the other half. Instead of waiting 30+ minutes (not exaggerating), we went up and down 16 flights of stairs. I felt awful for those on higher floors.\r\n\r\nThis is certainly not David's fault, but I hope it is fixed soon. It's ridiculous."},
#   {'_id': '65138444',
#    'date': datetime.datetime(2016, 3, 11, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '32991427',
#    'reviewer_name': 'Gilda',
#    'comments': "We stayed for 12 days and rented a car for a week. The parking is already included which is a bonus. The location is close to Ala Moana centre, the beach and convention centre in short, you can go anywhere you want using a bus or a trolley. The place has a comfortable bed and lots of clean towel. The only problem is the elevator because only 1 is working and most of the time it's broken. David was kind enough to help us bring down our luggages. "},
#   {'_id': '70789595',
#    'date': datetime.datetime(2016, 4, 20, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '1130379',
#    'reviewer_name': 'Edward & Yang Qian',
#    'comments': "With the exception of the lift, the apartment exceeded the description in AirBnB.  The apartment is good size for two people and very clean, the linens are of good quality and ample, and the kitchen is well equipped.  Of note are the windows which span 18 feet to provide good natural lighting, a partial view of the marina and ocean front, and good ventilation (we never used the A/C).  We were impressed with the location – walking distance to the hotel beaches, the Fort Derussy military facilities, Ala Moana Park and Shopping Mall, public transportation, restaurants, and convenience stores.  The elevator service for the 40 story/140 unit building  is an ongoing problem, with only one ten-person lift  operating “in slow mode for  safety” or not at all if winds are high.  You'll certainly need patience when gaining access to the apartment and possibly physical endurance to negotiate the stairs (we only had to climb the stairs 3 times in 2 weeks)."},
#   {'_id': '71782191',
#    'date': datetime.datetime(2016, 4, 28, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '40859330',
#    'reviewer_name': 'Natalie Jane',
#    'comments': 'This studio is fabulous ! Incredible location, steps away from everything. We found the studio as described, cosy and very well maintained with fresh towels and all other household amenities ready for us. The building was also very nice and quiet.\r\nParking space was a great plus!\r\nMoreover, David was a lovely host, always available to help and very quick at answering emails and enquiries.\r\nWe are certainly looking forward to coming back and staying in the exact same studio.'},
#   {'_id': '72782520',
#    'date': datetime.datetime(2016, 5, 4, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '42127882',
#    'reviewer_name': 'Laurie',
#    'comments': 'The host responded quickly to our questions. The area was great as it was close to the beach, restaurants and stores. '},
#   {'_id': '80380380',
#    'date': datetime.datetime(2016, 6, 17, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '20138706',
#    'reviewer_name': 'Park',
#    'comments': '이 숙소에 머물게 되어서 정말 행운이라고 생각합니다.\r\n위치도 정말 좋았고, 무엇보다 주차시설이 포함된 숙소여서 \r\n유용했습니다.\r\n\r\n방 안에서의 wi-fi도 잘 작동했으며, 다른 후기에서 엘레베이터에 대한 문제가 많아 보여 걱정했지만, 제가 묵었던 일정에는 전혀 문제되지 않았습니다.\r\n\r\n전반적으로 만족스러운 숙소였습니다.'},
#   {'_id': '82870741',
#    'date': datetime.datetime(2016, 6, 30, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '78897443',
#    'reviewer_name': 'Colin',
#    'comments': "David's instructions make arriving and checking in as easy as any hotel. The condo is in a great location and was a comfortable stay."},
#   {'_id': '84876745',
#    'date': datetime.datetime(2016, 7, 9, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '55986234',
#    'reviewer_name': 'Will',
#    'comments': 'Fantastic location very close to the beach and pick up spots for tours. The free parking space is in a secure parking garage and is very handy due to the lack of public parking in the area. The apartment itself is basic, but provides all the necessities and is good for the price. Only downsides are the noise of the AC and the hot water a bit inconsistent at times. David was very responsive to messages and we would highly recommend him as a host. Overall a great experience and we would definitely stay here in the future.'},
#   {'_id': '85836803',
#    'date': datetime.datetime(2016, 7, 13, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '36994169',
#    'reviewer_name': 'Gabriela',
#    'comments': 'La habitación era tal cual la descripción. El parking muy cómodo y la ubicación también. La wifi era rápida.\r\nAntes y durante la estadía, David respondió a mis consultas de forma sumamente ágil.\r\nFue muy buena y recomendable estadía.'},
#   {'_id': '87154164',
#    'date': datetime.datetime(2016, 7, 18, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '2459754',
#    'reviewer_name': 'Courtney',
#    'comments': "David's room is in Waikiki and a close walk to the Ala Moana mall, making it easy to find restaurants. The room itself was easily accessible, with the directions David provided, and was very clean when we arrived there. Everything is just as the post says, with a coin laundry, full kitchen, free parking, and enough room for 2 people. Would definitely stay here again."},
#   {'_id': '92168567',
#    'date': datetime.datetime(2016, 8, 7, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '435534',
#    'reviewer_name': 'Ian',
#    'comments': ' great locality , everything was fine , but a noisy air conditioner'},
#   {'_id': '98425794',
#    'date': datetime.datetime(2016, 8, 30, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '33938822',
#    'reviewer_name': 'Alex',
#    'comments': "David answered all my questions and instructions were clear and easy to follow. The condo was clean, well appointed and centrally located. A nice bonus was the parking space as finding cheap and accessible parking in the area is slim to none. I noticed a few complaints about the elevator but we had no issues during our stay of 2 weeks. I would definitely recommend David's place if you're looking to stay in Waikiki."},
#   {'_id': '101509630',
#    'date': datetime.datetime(2016, 9, 13, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '30617586',
#    'reviewer_name': 'Sigrid',
#    'comments': "Aloha, my husband and I had a wonderful 2 week stay at David's very conveniently located and fairly priced apartment. We were able to walk to the conference center for our event and to great beaches, restaurants and the world's largest outdoor mall. David was very easy to get a hold of and quick to respond to any questions we had. The apartment was clean and very functional. The elevator took time, especially at certain times during the day, but overall was not too inconvenient. We were grateful that we were able to park here too. We would recommend staying here and would like to stay again when we return "},
#   {'_id': '102393110',
#    'date': datetime.datetime(2016, 9, 18, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '35035651',
#    'reviewer_name': 'Xing',
#    'comments': 'Great host. Great communicator. Upgraded to another property in better location due to paint job at the original stay.'},
#   {'_id': '106187557',
#    'date': datetime.datetime(2016, 10, 4, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '23535107',
#    'reviewer_name': 'Rafael',
#    'comments': 'David is an amazing person. The flat has a good size, good view, the bed is good and whenever I needed had hot water in the shower. The lift system is undergoing renovation but only once waited for about 5 minutes, the other times I waited for the usual of a building of 40 floors. The parking space is a big deal because in that region the parking is very expensive. The flat is close to restaurants and is a few minutes walk from Waikiki Beach and Ala Moana mall. If I go back to Honolulu, I intend to stay again in this flat.'},
#   {'_id': '107511886',
#    'date': datetime.datetime(2016, 10, 10, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '89838175',
#    'reviewer_name': 'Rao',
#    'comments': 'Worried about single operating elevator. Fortunately we did not have any problem.'},
#   {'_id': '124940085',
#    'date': datetime.datetime(2017, 1, 3, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '64069523',
#    'reviewer_name': '(Email hidden by Airbnb)',
#    'comments': 'We only had contact with our host due to the problem with the TV ( no reception)  and the big problem with the elevator being out of order.  The area was centrally located. close to mall, restaurants and beach. We felt safe walking at night and day.'},
#   {'_id': '137659456',
#    'date': datetime.datetime(2017, 3, 16, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '32642028',
#    'reviewer_name': 'Karn',
#    'comments': "Enjoyed a great stay at David's apartment. Private room, decent views, excellent location. One downside would be only the single elevator in action but it wasn't a dealbreaker and an easy work around. Again, location here is key. This apartment is right in the heart of it in easy access to all the main Waikiki amenities. Parking on site was great too. Would def stay here again! Cheers. "},
#   {'_id': '140575131',
#    'date': datetime.datetime(2017, 3, 30, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '25085426',
#    'reviewer_name': 'Eiman',
#    'comments': 'We enjoyed very much in Oahu, the location was great it close to Wakiki beach.'},
#   {'_id': '221205568',
#    'date': datetime.datetime(2017, 12, 25, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '158906545',
#    'reviewer_name': 'Hwisun',
#    'comments': 'Very nice place to stay for a week :)'},
#   {'_id': '225890671',
#    'date': datetime.datetime(2018, 1, 7, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '20023935',
#    'reviewer_name': 'Todd',
#    'comments': "This was a great little place to stay. There's a nice view of the ocean, though distant. The place is close to everything (at least for us though we also don't mind walking). There are great restaurants at the Ala Moana mall. It's close to the Hilton. This place had everything we needed. We felt safe here. We enjoyed ourselves."},
#   {'_id': '226861563',
#    'date': datetime.datetime(2018, 1, 12, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '162182403',
#    'reviewer_name': 'Larry V',
#    'comments': 'Convenient , and private location, secured building with gated parking. AC worked very well.'},
#   {'_id': '228450253',
#    'date': datetime.datetime(2018, 1, 19, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '158348807',
#    'reviewer_name': 'Donna',
#    'comments': "Location is very near the ocean, Waikiki, Ala Moana the largest shopping mall in Hawaii, is just a five-minute drive away giving you easy access to over 340 shops, services and entertainment. The mall is just down the street or you could walk there, free parking at the mall if you do drive. Down the street on Kalakaua is Luxury Row. The world’s top fashion houses—Tiffany & Co., Coach, Yves Saint Laurent, Chanel, Gucci, Tod’s, Bottega Veneta and Hugo Boss it was fun to go in the shops. Having a free parking space is a bonus. The view of the marina and ocean was beautiful. I could see boats headed out to sea and parasailers. Laundry located on the 5th floor along with the ice machine if you're headed out for the day a small cooler was provided. Vending machines are on the 2nd floor or you can walk to the ABC store at the corner. Bed was soft and comfortable. Air-conditioner works perfectly or you can open the window for an ocean breeze. Great pressure in the shower and plenty of towels. If you want to eat in there is a microwave, stove and fridge. During busy times you may have to wait for the elevator, only 1 is working, but there are stairs."},
#   {'_id': '242428030',
#    'date': datetime.datetime(2018, 3, 11, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '168734883',
#    'reviewer_name': 'Chang Kong',
#    'comments': 'We were a little disappointed with the overall stay.  The place was not thoroughly cleaned. Everything was dusty or had not wiped down/ cleaned. Appliances were dirty so we did not use them and the sponge in the kitchen had hairs stuck on it. There was also hair on the floor and restroom. I feel like with the $75 cleaning fee, they needed to do a much better job. The TV had no reception so we weren’t able to use it. The mattress was pretty hard to sleep on. Although we were aware of the elevator issues, the wait for the elevator took up to 15 mins at times.\n\nWas located in a very nice location, close to everything. You could walk everywhere. The host was very nice and contacted us before arrival and before leaving.\n\nOverall, if you’re looking for a comfortable stay, I would suggest going to a hotel.'},
#   {'_id': '244565441',
#    'date': datetime.datetime(2018, 3, 18, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '172450613',
#    'reviewer_name': 'Amanda',
#    'comments': 'This is a great little apartment. Exactly as pictured. Great location. All of Waikiki is easily accessible either by walking, public transport or car. The big plus is the car space and wifi. David was easily contactable and was kind enough to let us check in early after a long overnight flight. No problem at all with the one lift.'},
#   {'_id': '246121341',
#    'date': datetime.datetime(2018, 3, 24, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '1497907',
#    'reviewer_name': 'Jeff',
#    'comments': "What an amazing location! Super clean too! The parking was pretty convenient too :) You may want to bring an extra blanket for the winter. One of the elevators isn't working but the one that is will be fast enough (usually a few minutes at most), you're on island time now after all. Lots of clean towels which is highly appreciated!! Be sure to get malasadas from Leonard's Bakery, then snorkel Hanauma Bay and eventually get spicy shrimp at Ted's Bakery :D"},
#   {'_id': '260723260',
#    'date': datetime.datetime(2018, 5, 5, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '58891646',
#    'reviewer_name': 'Galina',
#    'comments': 'Great location, close to great restaurants, bars and Ala Moana shopping center. Check-in was very easy. Free parking!!! The place was clean and had everything I needed. Definitely would stay again!'},
#   {'_id': '270936742',
#    'date': datetime.datetime(2018, 5, 30, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '40187249',
#    'reviewer_name': 'Rhonda',
#    'comments': "David's place is in a great location, short walk to beach, Ala Moana Centre / supermarket, buses 1 block away. Felt safe walking around even late at night. A good basic apartment with a great shower and fairly comfy bed."},
#   {'_id': '286685084',
#    'date': datetime.datetime(2018, 7, 6, 4, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '85152194',
#    'reviewer_name': 'James',
#    'comments': 'Great location!'},
#   {'_id': '353832369',
#    'date': datetime.datetime(2018, 11, 29, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '212464652',
#    'reviewer_name': 'Lianne',
#    'comments': 'We rate it 2/10.  It was dirty/sticky and falling apart-litterly doors falling off or missing-pictures are not accurate.. Floors under both sinks is rotten. Bed was horrible to sleep in.  Air conditioner super noisey.  A HUGE DISAPPOINTMENT'},
#   {'_id': '356310505',
#    'date': datetime.datetime(2018, 12, 7, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '228104726',
#    'reviewer_name': 'Eugene',
#    'comments': 'This rental was the first time I’ve rented lodging from Airbnb. \n\nI’m giving the review three stars instead of one star because of two reasons, \nDavid, the property manager, and the location, in Waikiki. \n\nDavid is a very nice man who listened to our concerns and acted to help out as much as he could.  David responded usually within two hours.  We were disappointed with the rental but David worked with us to adjust the rental fees.\n\nThe biggest issue we saw was that the condo was dirty.  With a cleaning fee of $100 and the nice pictures on the Airbnb website, we expected a mostly dust free and clean rental.  We talked with David about the dirty items (there were many) and a couple missing items.  He was apologetic and did his best to help salvage our stay. \n\nWe ended up leaving before the end of the rental agreement and David worked with us on that.  After our stay, David messaged me to say that the items I told him were all addressed.  I would recommend that the next renter message David and verify.\n\nBecause of the location, the free parking, and David, I would rent the condo again.'},
#   {'_id': '357822864',
#    'date': datetime.datetime(2018, 12, 11, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '222456905',
#    'reviewer_name': 'Shahin',
#    'comments': 'Great location, an awesome host. We had an issue with WiFi and David resolved the issue fast so we can enjoy our trip. Aloha!'},
#   {'_id': '359748878',
#    'date': datetime.datetime(2018, 12, 17, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '117032728',
#    'reviewer_name': 'Chaundra',
#    'comments': 'Good value and central location'},
#   {'_id': '363959231',
#    'date': datetime.datetime(2018, 12, 29, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '13231063',
#    'reviewer_name': 'Martina',
#    'comments': 'Great location, very comfortable especially because of the parking space inside the building. Easy check in-check out procedure. We experienced a elevators failure during Christmas holidays, so no maintenance was available for few days. The apt is on the 16th floor so climbing the stairs (small ramps of 7 steps each though) at least twice a day was quite annoying. The host offered spontanusly 255€ refund for the inconvenience.'},
#   {'_id': '400059558',
#    'date': datetime.datetime(2019, 1, 10, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '39615383',
#    'reviewer_name': 'Robert',
#    'comments': 'David was very helpful and accommodating!'},
#   {'_id': '407326158',
#    'date': datetime.datetime(2019, 2, 1, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '191075155',
#    'reviewer_name': 'Rhonda',
#    'comments': 'Great Location!!  Beware of only one working elevator for a 32 story building.  Not sure when the elevator work is going to be completed.  I just used the inconvenience as an opportunity to get my cardio in going up/down 16 flights of stairs each day.  Enjoyed my stay.  Thanks David!'},
#   {'_id': '409415200',
#    'date': datetime.datetime(2019, 2, 7, 5, 0),
#    'listing_id': '1001265',
#    'reviewer_id': '65980899',
#    'reviewer_name': 'Wendi',
#    'comments': 'This is a great location in Honolulu!  You can walk to Waikiki in less than 10 minutes.  You are  on a high floor, and can see the water and the mountains.  It is a good value for this location!'}]}

# %% [markdown]
# Filtramos viviendas con 2 baños y 3 dormitorios, con alguna review

# %%
list(records.find({'bathrooms':2,
                  'bedrooms':3,
                  'number_of_reviews':{'$ne':0}}).limit(3))
# Out:
# [{'_id': '10423504',
#   'listing_url': 'https://www.airbnb.com/rooms/10423504',
#   'name': 'Bondi Beach Dreaming 3-Bed House',
#   'summary': "This peaceful house in North Bondi is 300m to the beach and a minute's walk to cafes and bars. With 3 bedrooms, (can sleep up to 8) it is perfect for families, friends and pets. The kitchen was recently renovated and a new lounge and chairs installed. The house has a peaceful, airy, laidback vibe  - a perfect beach retreat. Longer-term bookings encouraged. Parking for one car. A parking permit for a second car can also be obtained on request.",
#   'space': "Serene space with three bedrooms, including a studio at the back, 300m to the beach and near to best cafes and bars in Bondi. Parking for one car. This wonderful house is designed to cater for families or groups with plenty of space and flexible bedding arrangements. There are three bedrooms including a master bedroom with a king bed, separate studio with a queen bed and a room with two single beds (with an additional two single trundle beds) that also can be converted into a king-sized bed. Just 300 metres to the beach, you'll find great cafes, bars and a small supermarket within a two-minute walk. The house has a front deck and back garden area. A new kitchen was recently installed with all mod cons including an induction cook top, Nespresso machine, dishwasher and microwave.  The foodies will love the good quality cookware and lots of bowls and platters for salad and food preparation. There is also a semi industrial vegetable juicer, orange juicer, soda stream machine and blender.  ",
#   'description': "This peaceful house in North Bondi is 300m to the beach and a minute's walk to cafes and bars. With 3 bedrooms, (can sleep up to 8) it is perfect for families, friends and pets. The kitchen was recently renovated and a new lounge and chairs installed. The house has a peaceful, airy, laidback vibe  - a perfect beach retreat. Longer-term bookings encouraged. Parking for one car. A parking permit for a second car can also be obtained on request. Serene space with three bedrooms, including a studio at the back, 300m to the beach and near to best cafes and bars in Bondi. Parking for one car. This wonderful house is designed to cater for families or groups with plenty of space and flexible bedding arrangements. There are three bedrooms including a master bedroom with a king bed, separate studio with a queen bed and a room with two single beds (with an additional two single trundle beds) that also can be converted into a king-sized bed. Just 300 metres to the beach, you'll find great cafes, b",
#   'neighborhood_overview': "North Bondi is laid back with great food and coffee. You can walk to low key wine bars or larger pubs or stay at home and enjoy a peaceful space. Favourite local haunts that are literally a two-minute walk away include the organic bakery (Organic Republic) on the corner, the local piadina cafe (La Piadina) and a great dumpling cafe and cocktail bar (Mamasan). Just a short stroll to the beach and buses to Bondi Junction where you'll find a giant Westfield shopping mall and connections to the city. Bondi Beach also has boutiques and other speciality shops like the famous Messina Gelato and Bills.",
#   'notes': 'Please nominate the correct number of guests before you arrive. There are extra charges for extra guests and if you do not declare guests I will make a resolution request to Airbnb and review you accordingly. Please note we have friendly neighbours and a security camera at the front gate.',
#   'transit': "There is parking for one car and a second car can be parked with a street permit arranged in advance.  It's a stroll to Bondi Beach or walk one minute around the corner to the bus stop where you will find buses to Bondi Junction and the city. All cafes, bars and supermarkets are in walking distance.",
#   'access': "The house has a front deck and back garden area.  I can be flexible with checkin and checkout when possible. If I can't  offer early checkin I can  offer bag drop (from 10.45am) before checkin at 3pm. If you require a super early checkin I offer a discounted rate to block the previous day.   It's also possible to checkin late in the day or night.",
#   'interaction': "The house is offered as a whole. I won't be around after I've checked you in but the neighbours have my phone number and will call me (or knock on the door politely) if there is loud music or a party that is disturbing them. Please note if guests don't consider neighbours they will he asked to leave.",
#   'house_rules': 'Guests should have Airbnb verification at time of booking. We expect guests to be respectful of our lovely neighbours and keep the noise down, especially after 10pm at night. No loud music at any time of day. That means no parties, move all social gatherings into the house after 10pm. No smoking inside the house. Pets welcome.',
#   'property_type': 'House',
#   'room_type': 'Entire home/apt',
#   'bed_type': 'Real Bed',
#   'minimum_nights': '2',
#   'maximum_nights': '1125',
#   'cancellation_policy': 'strict_14_with_grace_period',
#   'last_scraped': datetime.datetime(2019, 3, 7, 5, 0),
#   'calendar_last_scraped': datetime.datetime(2019, 3, 7, 5, 0),
#   'first_review': datetime.datetime(2016, 1, 30, 5, 0),
#   'last_review': datetime.datetime(2018, 11, 11, 5, 0),
#   'accommodates': 8,
#   'bedrooms': 3,
#   'beds': 6,
#   'number_of_reviews': 139,
#   'bathrooms': Decimal128('2.0'),
#   'amenities': ['TV',
#    'Internet',
#    'Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Paid parking off premises',
#    'Smoking allowed',
#    'Pets allowed',
#    'Indoor fireplace',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Private entrance',
#    'Bathtub',
#    'High chair',
#    'Fireplace guards',
#    'Pack ’n Play/travel crib',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Ethernet connection',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Single level home',
#    'BBQ grill',
#    'Patio or balcony',
#    'Garden or backyard',
#    'Luggage dropoff allowed',
#    'Long term stays allowed'],
#   'price': Decimal128('399.00'),
#   'weekly_price': Decimal128('2369.00'),
#   'monthly_price': Decimal128('8802.00'),
#   'security_deposit': Decimal128('1000.00'),
#   'cleaning_fee': Decimal128('185.00'),
#   'extra_people': Decimal128('35.00'),
#   'guests_included': Decimal128('6'),
#   'images': {'thumbnail_url': '',
#    'medium_url': '',
#    'picture_url': 'https://a0.muscache.com/im/pictures/3e7cc29d-813d-407c-ae90-b6f2745cd384.jpg?aki_policy=large',
#    'xl_picture_url': ''},
#   'host': {'host_id': '2509326',
#    'host_url': 'https://www.airbnb.com/users/show/2509326',
#    'host_name': 'Cat',
#    'host_location': 'AU',
#    'host_about': 'I like furry friends and stylish surrounds.',
#    'host_response_time': 'within an hour',
#    'host_thumbnail_url': 'https://a0.muscache.com/im/users/2509326/profile_pic/1352810233/original.jpg?aki_policy=profile_small',
#    'host_picture_url': 'https://a0.muscache.com/im/users/2509326/profile_pic/1352810233/original.jpg?aki_policy=profile_x_medium',
#    'host_neighbourhood': 'North Bondi',
#    'host_response_rate': 100,
#    'host_is_superhost': False,
#    'host_has_profile_pic': True,
#    'host_identity_verified': True,
#    'host_listings_count': 5,
#    'host_total_listings_count': 5,
#    'host_verifications': ['email',
#     'phone',
#     'reviews',
#     'jumio',
#     'offline_government_id',
#     'government_id']},
#   'address': {'street': 'Bondi Beach, NSW, Australia',
#    'suburb': 'Bondi Beach',
#    'government_area': 'Waverley',
#    'market': 'Sydney',
#    'country': 'Australia',
#    'country_code': 'AU',
#    'location': {'type': 'Point',
#     'coordinates': [151.27448, -33.8872],
#     'is_location_exact': False}},
#   'availability': {'availability_30': 0,
#    'availability_60': 0,
#    'availability_90': 0,
#    'availability_365': 0},
#   'review_scores': {'review_scores_accuracy': 10,
#    'review_scores_cleanliness': 10,
#    'review_scores_checkin': 10,
#    'review_scores_communication': 10,
#    'review_scores_location': 10,
#    'review_scores_value': 9,
#    'review_scores_rating': 96},
#   'reviews': [{'_id': '60998110',
#     'date': datetime.datetime(2016, 1, 30, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '24727941',
#     'reviewer_name': 'Arthur',
#     'comments': 'Great House. Only there for two nights. Conveniently located good vibe'},
#    {'_id': '61200138',
#     'date': datetime.datetime(2016, 2, 1, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '53854835',
#     'reviewer_name': 'Sharon',
#     'comments': 'Our stay at Bondi was lovely. Cat welcomed me, was friendly and helpful. The house was very comfy. Close to the beach, coffee shops & cafes. Unfortunately the mozzies were a bother in the only bedroom without nets but this was overcome with extra spray.  And parking is a bother but that is how it is in Bondi. I can recommend and would stay there again. '},
#    {'_id': '62001406',
#     'date': datetime.datetime(2016, 2, 10, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '774899',
#     'reviewer_name': 'Sarah',
#     'comments': 'We loved staying in this house. We had 4 sisters and our mother for a relaxing 5 night stay. There were two bathrooms which was perfect and the house was cosy and clean. Great little backyard for a few wines in the sun. Thank you.'},
#    {'_id': '62307810',
#     'date': datetime.datetime(2016, 2, 13, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '57696096',
#     'reviewer_name': 'Yael',
#     'comments': 'Great house and location. Peaceful and comfortable - and close to the beach and Bondi buzz. Cat was welcoming and helpful. Fresh coffee and milk in fridge was a nice touch.'},
#    {'_id': '62526749',
#     'date': datetime.datetime(2016, 2, 15, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '938333',
#     'reviewer_name': 'Tania',
#     'comments': 'Great pad in the heart of Bondi. A Feeling of absolute calm when you walk in. Great proximity to the beach, cafes and bars. House has everything you need for a short or long stay. '},
#    {'_id': '63112982',
#     'date': datetime.datetime(2016, 2, 20, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '51895951',
#     'reviewer_name': 'Jay',
#     'comments': "It was great time at Cat's place. Very close to bondi beach about 5 mins walk. And quiet and relax beautiful place. I love to stay again when my next visit. My family was happy too:)\nThanks again Cat:)"},
#    {'_id': '63354922',
#     'date': datetime.datetime(2016, 2, 22, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '40057503',
#     'reviewer_name': 'Alex',
#     'comments': "Cats place is a very relaxing environment. Perfectly situated, close to the beach and shops. She's very helpful and always replies to your requests. You couldn't ask for a better house/host."},
#    {'_id': '63832532',
#     'date': datetime.datetime(2016, 2, 27, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '59073064',
#     'reviewer_name': 'Emily',
#     'comments': "Cat's flat was ideal for our needs -- three generations visiting North Bondi together. Two bathrooms felt like luxury (as did the king size bed), and the flat was super convenient to great restaurants (Mamasan and Avila were both tasty in their own ways, and right around the corner) and the beach. Shopping and tasty gelato (our kids were staunch advocates for the Messina Gelato) were only a slight stone's throw further away on Hall St. \r\n\r\nHaving coffee available in the morning was a particular treat (thank you again, Cat), and there were ample cookbooks to review if we had had the time to really use the kitchen. Communications with Cat were easy for checking in and out; we didn't need to trouble her during our visit because the replacement light bulbs were easy to find when one fixture burnt out. We would definitely consider staying here again. "},
#    {'_id': '64123161',
#     'date': datetime.datetime(2016, 2, 29, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '58412346',
#     'reviewer_name': 'Mary',
#     'comments': 'Had a great weekend away with friends. Great house and location walking distance to cafes and the beach. Amenities were good and Cat also provided beach towels for us to use. Would definitely come back.'},
#    {'_id': '64388457',
#     'date': datetime.datetime(2016, 3, 3, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '10335122',
#     'reviewer_name': 'Ashwami',
#     'comments': "Cat was a great host. The house is lovely, very close to the beach, a great organic bakery and restaurants. The kitchen was well stocked with basic essentials and some cookbooks. Cat was very quick to help out when I couldn't find the water heater switch. Would definitely recommend this house for anybody who wants to stay at Bondi. "},
#    {'_id': '64797569',
#     'date': datetime.datetime(2016, 3, 8, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '55357270',
#     'reviewer_name': 'Alex',
#     'comments': 'Myself and 5 friends stayed in the house for 4 nights and had a great time. The house is an amazing beach house. Good room sizes and lounge area. 3min walk to the beach and a wide range of cafes near by. 10/10!'},
#    {'_id': '65175672',
#     'date': datetime.datetime(2016, 3, 11, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '36701868',
#     'reviewer_name': 'Tong',
#     'comments': 'The house is near the Bondi Beach,about 15minutes drive to City｡Nice house…'},
#    {'_id': '65517816',
#     'date': datetime.datetime(2016, 3, 15, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '15656343',
#     'reviewer_name': 'Gemma',
#     'comments': 'Cat was very flexible allowing us to check in early & leave our bags until later in the day when checking out. The house was great, it had everything we needed & Cat was very prompt with dropping over a hair dryer when we needed one! Such a relaxing space & so close to everything! Perfect for our girls trip. Would love to return in winter to make use of the great fireplace!'},
#    {'_id': '65945043',
#     'date': datetime.datetime(2016, 3, 18, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '15278048',
#     'reviewer_name': 'Marlène',
#     'comments': "Wow! Cat's place is amazing, well located, lot of shops, coffees (Jed's is a dream) around, a perfect beach house! I'd love to come back very soon!! Cat was very flexible with the chek-out, we had an extra afternoon at beach."},
#    {'_id': '66390378',
#     'date': datetime.datetime(2016, 3, 22, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '11616569',
#     'reviewer_name': 'Patrick',
#     'comments': 'Cat was extremely attentive in providing for my families needs. She was flexible with check in times and the house was well presented and very much as described. A lovely experience.'},
#    {'_id': '66888062',
#     'date': datetime.datetime(2016, 3, 25, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '13895193',
#     'reviewer_name': 'Nichole',
#     'comments': "Spacious beautiful Australian home. Its location couldn't have been any better; the beach, bus stop, and grocery store were only a short walk away. Cat was very accommodating, had a well kept home, and fast internet. Our only regret was that we couldn't stay longer. "},
#    {'_id': '67227988',
#     'date': datetime.datetime(2016, 3, 27, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '23790649',
#     'reviewer_name': 'Danielle',
#     'comments': "The place was beautiful and so so close to the beach and cafes! It was the perfect girls weekend away and we all left feeling super relaxed! The place is exactly like the pictures. I've already recommended Cat's place to many friends. Thanks Cat."},
#    {'_id': '69070992',
#     'date': datetime.datetime(2016, 4, 9, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '18053935',
#     'reviewer_name': 'Carole',
#     'comments': "Cat made us feel really welcome, the house was clean and tidy, great facilities and great location, close to the beach but not on a busy road.  The house was ideal for us, two families and our mother in the 'annex'. We would definitely recommend the property and would return."},
#    {'_id': '69534451',
#     'date': datetime.datetime(2016, 4, 11, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '50942924',
#     'reviewer_name': 'Venesa',
#     'comments': 'Relaxed vibe, perfect for families or couples, fabulous location, close to great shops, restaurants and iconic Bondi Beach.'},
#    {'_id': '70327363',
#     'date': datetime.datetime(2016, 4, 17, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '62839865',
#     'reviewer_name': 'Vanessa',
#     'comments': 'From start to finish, our stay at Bondi Beach Dreaming was enjoyable.  It was homely and comfortable and kitted out with just about everything you could possibly need.  Will definitely book again here.  It is a short walk to Bondi beach, and shops, bars and cafes.  It felt safe, secure and private.  The beds and linen were comfortable and high quality, and the overall feel, was like being at our "home away from home".'},
#    {'_id': '71407790',
#     'date': datetime.datetime(2016, 4, 25, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '46527001',
#     'reviewer_name': 'Lauren',
#     'comments': 'Great house and location, walking distance to everything in Bondi! Very spacious rooms with everything you need, would definitely stay again. Cat was great to deal with and very helpful.'},
#    {'_id': '73476947',
#     'date': datetime.datetime(2016, 5, 8, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '2301458',
#     'reviewer_name': 'Cecelia',
#     'comments': 'Fabulous location and lovely living and dining area, big enough for our group of 8, however there wasn’t 8 adult beds. Probably should be advertised as 6 adults 2 children, the 2 trundle beds were smaller than a single bed an our 5 ft 2 inch companions feet hung off end.\r\n\r\nVery generous with late check out.\r\n\r\nDefinitely would stay there again.\r\n'},
#    {'_id': '74521500',
#     'date': datetime.datetime(2016, 5, 15, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '14577072',
#     'reviewer_name': 'Tom',
#     'comments': 'Cat was a great host and catered for our large family group really well!\r\nThe place itself is very charming and its proximity to the weekend market, the shops and the beach is pretty unbeatable.\r\n\r\nHighly recommend Cat, and highly recommend the place!\r\nThanks! '},
#    {'_id': '76788925',
#     'date': datetime.datetime(2016, 5, 29, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '2263177',
#     'reviewer_name': 'Ashleigh',
#     'comments': "Absolutely loved our stay at Cat's place! Fantastic location and beautiful home. Cat was extremely helpful and a great host. Highly recommend!"},
#    {'_id': '78144565',
#     'date': datetime.datetime(2016, 6, 5, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '27186228',
#     'reviewer_name': 'Jess',
#     'comments': '6 friends and I stayed at Cats lovely house for a weekend and had the best time (apart from the torrential rain)! \nCats house has everything you need including an open fire you can light, wood provided. I will definitely book again with a group or even take my family for a trip away. \nCat was fantastic to communicate with, responding very quickly. \nThank you Cat!!'},
#    {'_id': '79001040',
#     'date': datetime.datetime(2016, 6, 10, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '2397541',
#     'reviewer_name': 'Jon',
#     'comments': 'Great place and awesome location next to some great food. Cat was easy going and flexible on arrival and check out.'},
#    {'_id': '81093097',
#     'date': datetime.datetime(2016, 6, 20, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '30906519',
#     'reviewer_name': 'John',
#     'comments': 'Great place and location but needs fixing up. Thankfully Cat was very helpful and responsive to our request.'},
#    {'_id': '81786290',
#     'date': datetime.datetime(2016, 6, 25, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '23544694',
#     'reviewer_name': 'Shannon',
#     'comments': "Cat wasn't there to meet us but we had a fantastic time! The house was a comfortable distance from the hustle and bustle of the centre of Bondi, and only a short walk away from the sea side. Cat's Neighbours were also really friendly and hospitable. Ready to offer us assistance whenever. The heating in the house was great during winter and the wifi was fantastic! The check in process was quick. The kitchen and pantry were really well stocked and the houses was prepped to perfection with small thoughtful things like an international plug adaptor that we had forgotten to bring. Thanks Cat for the lovely stay!! "},
#    {'_id': '82650074',
#     'date': datetime.datetime(2016, 6, 28, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '65785307',
#     'reviewer_name': 'Troy',
#     'comments': '\r\nOK'},
#    {'_id': '84682779',
#     'date': datetime.datetime(2016, 7, 8, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '67646936',
#     'reviewer_name': 'Tanya',
#     'comments': "Best place to stay, Cat is lovely and very helpful, so close to everything and Cat's place is super clean,feels like home and we all had a ball, kids had fun and we loved the kitchen, we will stay again, hoping in summer , as said before, everything close , great restaurants, shopping,  transport  and everything  few minutes walk , thanks again Cat, we all loved Bondi\nCheers "},
#    {'_id': '85182100',
#     'date': datetime.datetime(2016, 7, 10, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '70111131',
#     'reviewer_name': 'Matt',
#     'comments': "Cat's place suited our needs perfectly. It was clean, comfortable, had plenty of amenities and was close to bars, cafes and the beach. Communication was really easy and Cat responded to any of my questions within minutes. We would not hesitate to stay there again."},
#    {'_id': '86377445',
#     'date': datetime.datetime(2016, 7, 16, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '31200167',
#     'reviewer_name': 'Catherine',
#     'comments': "Cat's house was in the best location. Just around the corner from great coffee shops and just a short walk to Bondi Beach. Bondi Beach itself is still only a 15 minute car ride to the city so it was terrific. The place was lovely and clean and beds very comfortable."},
#    {'_id': '90249890',
#     'date': datetime.datetime(2016, 7, 31, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '36387875',
#     'reviewer_name': 'Melanie',
#     'comments': 'House was warm and decor fantastic. Had a great stay. Cat communicated promptly throughout.'},
#    {'_id': '96433764',
#     'date': datetime.datetime(2016, 8, 22, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '68669463',
#     'reviewer_name': 'Paul',
#     'comments': "We really enjoyed the our stay at Cat's in Bondi. The location was great, and the home itself was a good fit for the two families of 4 who stayed there for a couple nights."},
#    {'_id': '97889056',
#     'date': datetime.datetime(2016, 8, 28, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '37828582',
#     'reviewer_name': 'Kathryn',
#     'comments': "Great central location only a short walk from the beach, loved all of Cat's recommendations for the area and LOVED the fireplace!  Really homely and comfortable."},
#    {'_id': '99759890',
#     'date': datetime.datetime(2016, 9, 5, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '59985367',
#     'reviewer_name': 'Gail',
#     'comments': 'We loved the vibe of the house, it was comfortable, had a great atmosphere and suited us perfectly. The neighbourhood is full of character and laid back, near the beach and shops, all round great for us.'},
#    {'_id': '100336640',
#     'date': datetime.datetime(2016, 9, 8, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '93777712',
#     'reviewer_name': 'Benjamin',
#     'comments': 'Fantastic place everything you want and more.. we enjoyed our time at cats bondi home entirely...!!'},
#    {'_id': '101093443',
#     'date': datetime.datetime(2016, 9, 11, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '68995097',
#     'reviewer_name': 'Melissa',
#     'comments': "We had a wonderful stay at Cat's place"},
#    {'_id': '101880294',
#     'date': datetime.datetime(2016, 9, 15, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '880639',
#     'reviewer_name': 'Lee',
#     'comments': 'Great stay \nFabulous location \nWould definately stay again \nHomely \nClean \nEverything we needed and some! \nThank you Cat!'},
#    {'_id': '102748438',
#     'date': datetime.datetime(2016, 9, 19, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '68142965',
#     'reviewer_name': 'Katie',
#     'comments': "Such a gorgeous oasis. The photos in the listing don't do it justice. It was such an enjoyable stay."},
#    {'_id': '103302618',
#     'date': datetime.datetime(2016, 9, 21, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '92072634',
#     'reviewer_name': 'Christina',
#     'comments': 'Great value, great location and very responsive host. Thanks for having us, Cat. '},
#    {'_id': '104518027',
#     'date': datetime.datetime(2016, 9, 26, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '52991096',
#     'reviewer_name': 'Amanda',
#     'comments': "A perfect getaway for our girls weekend away! Great location close to the beach as well as some amazing places to eat and drink. Cat's place was homely and welcoming and the ideal amount of space for 5 people."},
#    {'_id': '106015191',
#     'date': datetime.datetime(2016, 10, 3, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '22114301',
#     'reviewer_name': 'Erica',
#     'comments': 'Great stay at Cats house in Bondi! It was everything were after and more. Could not ask for a more perfect location. The house was clean and tidy and the bakery on the corner is to die for, we visited there every morning! Will definately stay again and recommend to all.'},
#    {'_id': '106910229',
#     'date': datetime.datetime(2016, 10, 8, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '16852954',
#     'reviewer_name': 'Kerry',
#     'comments': "Had a great time at our reunion because Cat's place lived up to the photos and description and was just perfect for us."},
#    {'_id': '107515458',
#     'date': datetime.datetime(2016, 10, 10, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '93362688',
#     'reviewer_name': 'Stephanie',
#     'comments': 'Great house and location'},
#    {'_id': '108327146',
#     'date': datetime.datetime(2016, 10, 15, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '54394681',
#     'reviewer_name': 'Emily',
#     'comments': "Cat's house was great - exactly as described, awesome location close to everything! The house was clean, and the space worked really well - especially since we had 3 kids with us, who were able to spread out and play without getting under our feet! Cat was a very accomodating host, great communication and we felt really comfortable. The little extra touches like extra blankets and towels, and lovely soaps / shampoos in the bathrooms just topped it off! I would highly recommend staying at Cat's place. "},
#    {'_id': '109302400',
#     'date': datetime.datetime(2016, 10, 20, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '12808070',
#     'reviewer_name': 'Tanguy',
#     'comments': 'Very nice family house, well equipped, close to the beach! Very nice breakfasts at the corner juste on the left! '},
#    {'_id': '110017589',
#     'date': datetime.datetime(2016, 10, 23, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '49234648',
#     'reviewer_name': 'Jessica',
#     'comments': "I organized a weekend away with 4 of my girlfriends and me at Cats place in Bondi the weekend just gone. I was so impressed with the funky beach house and amazing location! The house was fully equipped with everything we needed for the weekend including shampoo & conditioner, beach towels even milk in the fridge. I couldn't recommend this place more if you are looking for a relaxing weekend away with friends or other couples, it was situated within easy walking distance to the general store, awesome little bakery and beach road hotel. We thoroughly enjoyed breakfast at the local Harrys café yesterday morning also. Thanks so much Cat, I will definitely be back :) "},
#    {'_id': '111035329',
#     'date': datetime.datetime(2016, 10, 29, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '63676827',
#     'reviewer_name': 'Bianca',
#     'comments': 'Our stay was fantastic. The house is in a perfect location and is very eclectic & funky. Cat (the owner) was fabulous. She answered any questions I had during our stay straight away and was very helpful. Highly recommend :)'},
#    {'_id': '112815979',
#     'date': datetime.datetime(2016, 11, 7, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '8561188',
#     'reviewer_name': 'Jaye',
#     'comments': 'The host canceled this reservation 32 days before arrival. This is an automated posting.'},
#    {'_id': '113288173',
#     'date': datetime.datetime(2016, 11, 11, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '3879401',
#     'reviewer_name': 'Matt',
#     'comments': 'We had a fantastic time in Bondi. Thanks Cat, your house is lovely. Comms were always prompt and very helpful.'},
#    {'_id': '116289530',
#     'date': datetime.datetime(2016, 11, 29, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '44932892',
#     'reviewer_name': 'Tyson',
#     'comments': 'Coordinating the check-in time and receiving the keys was effortless and smooth which is always much appreciated. The apartment is a few minutes walk from the beaches and the shops. There is also a cafe at the end of the block which was even more convenient for morning coffee/breakfast. Would definitely recommend!'},
#    {'_id': '116584252',
#     'date': datetime.datetime(2016, 12, 1, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '10439717',
#     'reviewer_name': 'Tammy',
#     'comments': "We live near Portland, Oregon in the USA and it prides itself on being hip and weird. Bondi Beach must be its sister city times two. As a bunch of aged birdwatchers we didn't really fit in but felt comfortable and accepted anyway. Lots of shops and good restaurants within easy walking distance, and the beach is just as close. There's even a funky little nine hole golf course close by. It's perched on a cliff that overlooks the ocean and has million dollar views.\n\nThe house worked well for five adults (one couple and three others) and was clean and well appointed. There are even cookbooks displayed in the kitchen in case you wanted to get adventurous. One of the bedrooms is in a guesthouse in the back yard and it was a nice place for the couple to sleep and be apart form the others. Be prepared for visiting bugs, though.\n\nBelieve Cat when she says that you won't be able to park inside the gate without a high clearance vehicle but you will be able to park in the driveway if your car is on the small side. We had a minivan that was simply too big to allow for pedestrians pushing baby strollers to get by. Parking on the street is for two hours only and the nearest long-term free parking is s few blocks away. Remember to always leave space between you and the next car as locals seem to have no issue with pinning you in if you don't. \n\nCat was great about communicating with us. She seemed available at all times, promptly answering any questions that we had.\n\nEric\nVancouver, WA \nUSA"},
#    {'_id': '124881102',
#     'date': datetime.datetime(2017, 1, 2, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '56832913',
#     'reviewer_name': 'Lorraine',
#     'comments': "This accommodation is in a lovely location, quiet close to the beach. There was some miscommunication at the beginning, but Cat was exceptional in communication and sorting matters out straight away. \nThe accommodation was very rustic with all mod cons, but in need of some refurbishment with the kitchen, which is due to be done after our visit. \nThe location is easy to get into Sydney central with good transport links. It's also close to the stadiums and Bondi Junction shopping centre.\nI would recommend this property for a relaxed stay. Thank you Cat!"},
#    {'_id': '129313054',
#     'date': datetime.datetime(2017, 1, 30, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '69285232',
#     'reviewer_name': 'Shelley',
#     'comments': 'what a perfect spot a really beautiful place .'},
#    {'_id': '131654550',
#     'date': datetime.datetime(2017, 2, 12, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '74987205',
#     'reviewer_name': 'Anna',
#     'comments': 'Excellent stay at Bondi. All you can want in closeness to restaurants, the beach, busses and still have a secluded feel to it. The house had everything we needed and it was great for the kids also. We can highly recommend the house and the host Cat.'},
#    {'_id': '134028928',
#     'date': datetime.datetime(2017, 2, 25, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '66443058',
#     'reviewer_name': 'Bernadette',
#     'comments': 'We stayed at cats place, travelling from the uk , for our daughters wedding in Sydney .\nThere were 6 members of extended family staying together.\nCats place was very homely and cosy, there were lots of extras included, quality toiletries , sun cream and a very well stocked larder that we were encouraged to use.\nwe were left to enjoy our time at the property , and any questions we had were answered promptly by Cat .\nHighly recommended'},
#    {'_id': '134342425',
#     'date': datetime.datetime(2017, 2, 26, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '30324625',
#     'reviewer_name': 'Claire',
#     'comments': 'The house was perfect for what we needed!  Tranquil and close to shops beach bars and restaurants. Great communication from Cat.'},
#    {'_id': '135039368',
#     'date': datetime.datetime(2017, 3, 2, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '6211172',
#     'reviewer_name': 'Blaire',
#     'comments': "Good place for staying in Bondi. Unfortunately it was raining the whole time we were there so we couldn't really enjoy the nice outside space, which would have made the place a little more open and welcoming. "},
#    {'_id': '135360504',
#     'date': datetime.datetime(2017, 3, 4, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '51375260',
#     'reviewer_name': 'Cameron',
#     'comments': "Having previously lived in Bondi, we were pleased to discover Cat's quiet beach bungalow. Great proximity to everything in Bondi - just next door to the weekend markets at the local school, 3 minute walk to the beach. The house has lots of space - we had no issues with 8 adults and a baby. Cat was an excellent host. Enjoy your stay!"},
#    {'_id': '136287493',
#     'date': datetime.datetime(2017, 3, 9, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '30431326',
#     'reviewer_name': 'Craig',
#     'comments': 'The perfect Australian beach break, in the heart of Sydney'},
#    {'_id': '136998570',
#     'date': datetime.datetime(2017, 3, 12, 5, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '2539803',
#     'reviewer_name': 'Tamar',
#     'comments': 'It was wonderful to be based in such a fantastic location for a long weekend of sunshine in Sydney! Cat was very responsive and helpful with all our requests. The house is clean, very well equipped and suited our family holiday of 3 generations perfectly. We would highly recommend this place to anyone looking for a beachside place to stay.'},
#    {'_id': '137682038',
#     'date': datetime.datetime(2017, 3, 16, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '52985976',
#     'reviewer_name': 'Sharyn',
#     'comments': 'A terrific stay in a lovely house near the beach. Host was always ready to respond and let us have an early check in if possible.'},
#    {'_id': '137852769',
#     'date': datetime.datetime(2017, 3, 17, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '100151990',
#     'reviewer_name': 'Luke',
#     'comments': 'Fantastic home. Cat was a great host. We had a wonderful stay!'},
#    {'_id': '139901453',
#     'date': datetime.datetime(2017, 3, 26, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '8579897',
#     'reviewer_name': 'Joanne',
#     'comments': 'Great location, straightforward communication, well equipped kitchen. Close to great cafes and Bondi beach. Well recommended'},
#    {'_id': '140269362',
#     'date': datetime.datetime(2017, 3, 28, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '85984362',
#     'reviewer_name': 'Meg',
#     'comments': 'Great location - close to pretty much anything you could need.'},
#    {'_id': '140987903',
#     'date': datetime.datetime(2017, 4, 1, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '18363736',
#     'reviewer_name': 'Jevon',
#     'comments': 'A beautiful house. Very large and comfortable, with ample inside and outside spaces. We chose this address to prepare for a wedding. It was perfect. Cat was always available and attended to every need.'},
#    {'_id': '142992932',
#     'date': datetime.datetime(2017, 4, 9, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '14456960',
#     'reviewer_name': 'Emma',
#     'comments': 'This place was in a fantastic location. The house was large and very tidy. Cat was very easy to communicate with. Highly recommend for a comfortable stay.'},
#    {'_id': '146413047',
#     'date': datetime.datetime(2017, 4, 22, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '84403848',
#     'reviewer_name': 'Rhiannon',
#     'comments': 'The property was exactly as presented, immaculately clean and relaxing upon arrival. Beautiful open space and only a short walk from the main road. Little extras like quality bathroom products and comfortable beds made a huge difference. We will definitely be back.'},
#    {'_id': '147636071',
#     'date': datetime.datetime(2017, 4, 28, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '51022972',
#     'reviewer_name': 'Scott',
#     'comments': "Cat's place out the back of North Bondi is literally around the corner from a hip local scene with good grocers, bar and cafe action. The house is spectacular - classy and comfortable and in excellent taste. Cat is a genuine host and communicates extremely well. If this is the size and location you need, you'll not find better."},
#    {'_id': '148484938',
#     'date': datetime.datetime(2017, 4, 30, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '10079047',
#     'reviewer_name': 'Meredith',
#     'comments': "Cat's place was warm and welcoming, had everything we needed and was in a wonderful location close to Bondi beach but far enough away to be (Email hidden by Airbnb) munication was easy and prompt.  The house was perfect for a group of friends or a couple of families.  I would be happy to stay again. "},
#    {'_id': '149991444',
#     'date': datetime.datetime(2017, 5, 6, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '106174251',
#     'reviewer_name': 'Lauren',
#     'comments': "Cat's place was perfect for our girls getaway.  Amazing location, right next to Bondi Beach with a market and Harry's Expresso on the corner.  We walked everywhere.  Lovely, clean and funky décor, great outdoor entertaining space and plenty of beds.  Loved it, thank you."},
#    {'_id': '151669954',
#     'date': datetime.datetime(2017, 5, 13, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '121424484',
#     'reviewer_name': 'HuiSee',
#     'comments': 'Great house, great location. Just a few minutes walk to the beautiful bondi beach!'},
#    {'_id': '155815270',
#     'date': datetime.datetime(2017, 5, 28, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '5093738',
#     'reviewer_name': 'Maria Paz',
#     'comments': 'The house has everything you need and more.  wonderful location just steps away from great coffee and. rea shops and a stroll to the beach. s'},
#    {'_id': '157394180',
#     'date': datetime.datetime(2017, 6, 3, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '48440775',
#     'reviewer_name': 'Priscilla',
#     'comments': "This house is perfect !! It's in a fantastic location and really made our trip one to remember. Beautiful home and had everything you could need. Cat is a great host In all ways !! \nCannot rave enough about this place and you will not be disappointed in any way !!! "},
#    {'_id': '162426217',
#     'date': datetime.datetime(2017, 6, 20, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '65814071',
#     'reviewer_name': 'Jessica',
#     'comments': 'Great location. Easy walk to the beach. An assortment of restaurants down the hill. The house was everything it said it would be. Recommended.'},
#    {'_id': '163463947',
#     'date': datetime.datetime(2017, 6, 24, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '21780799',
#     'reviewer_name': 'Emma',
#     'comments': "We spent a lovely weekend at Cat's place and everything was perfect from the communication, an option to check out late and the most amazing beds! Thank you Cat we would love to stay here again!"},
#    {'_id': '169237785',
#     'date': datetime.datetime(2017, 7, 11, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '15615523',
#     'reviewer_name': 'Tom',
#     'comments': 'Cute traditional Sydney house, in a super location- away from the crazy touristy parts of Bondi, but close to the beach and in the more charming part of this ever-vibrant part of Sydney.\nEquipped with everything you need, and close to plenty of good bus routes.\nA bit chilly in this very cold spell of winter, but there are a couple of portable heaters.'},
#    {'_id': '169833252',
#     'date': datetime.datetime(2017, 7, 14, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '108663586',
#     'reviewer_name': 'Kelli',
#     'comments': 'Cute place with easy access to bondi and yummy food. A little cold at night through the winter, so if you travel with small children bring extra layers for sleeping! '},
#    {'_id': '170536849',
#     'date': datetime.datetime(2017, 7, 16, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '120680627',
#     'reviewer_name': 'Melissa',
#     'comments': 'Fantastic location. Walking distance to everything. Accomodation outstanding and the host was amazing. Would not hesitate to return.'},
#    {'_id': '172103142',
#     'date': datetime.datetime(2017, 7, 19, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '76885504',
#     'reviewer_name': 'Matthijs',
#     'comments': 'Great location, very nice house. Cat had been great in answerring all possible questions'},
#    {'_id': '173780019',
#     'date': datetime.datetime(2017, 7, 24, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '60157548',
#     'reviewer_name': 'Lucy',
#     'comments': 'Fantastic location, great apartment set up and responsive and accommodating hosts. '},
#    {'_id': '176865239',
#     'date': datetime.datetime(2017, 8, 1, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '42379393',
#     'reviewer_name': 'Kylie',
#     'comments': "Amazing location and every little detail in the house has been well thought out. Fantastic for extended families and groups. We can't wait to come back."},
#    {'_id': '182072806',
#     'date': datetime.datetime(2017, 8, 13, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '87637542',
#     'reviewer_name': 'Lyn',
#     'comments': "Cat's place was great, location was fantastic, a short walk to restaurants and the shops.  The corner shop cafe was very warm and welcoming and a really funky place to have a light meal or just a coffee. The house was very comfortable for a group of friends or family.  What struck us was the open plan living and plenty of lovely places to sit outside or on the porch or back deck.  Very nice.. would definetely stay again."},
#    {'_id': '185154808',
#     'date': datetime.datetime(2017, 8, 21, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '985873',
#     'reviewer_name': 'Katia',
#     'comments': "Le logement est parfait pour 2 familles, nous étions 2 couples avec 4 enfants et l'espace était assez grand pour tout le monde et bien pensé (1 chambre en bungalow en extérieur avec douche/toilette).\nLe logement était propre (intérieur/extérieur), tout était prêt pour notre arrivée (hiver à Sydney) couettes sur les lits, bouillottes, radiateurs à disposition et la cheminée feu de bois ! génial ! (vraiment appréciable pour la saison). \nLe logement est vraiment joli, coquet. On s'y sent bien. C'est confortable (lit douillet) et bien aménagé.\nLes enfants ont appréciés l'espace extérieur, le bassin à poissons.\nLa communication avec l'hôte a été bien organisé, aucun problème pour récupérer les clés. \nLe logement est extrèmement bien situé, c'est résidentiel, calme dans le sens ou se sont surtout des familles qui y vivent, c'est près mais aussi loin de l'agitation des bars et restos...branchés de Bondi.\nEndroit très près de la plage et de l'arrêt de bus (1 min à pieds), très pratique lorsque l'on est avec des enfants. \nSympa d'être juste à côté du marché de Bondi du samedi dimanche.\nJuste le seul point qui peut être un inconvénient pour certains : l'isolation, ce n'est pas bien isolé pour l'hiver mais c'est partout pareil dans les maisons en Australie (cela doit être appréciable en été !), et pour le bruit de la route (camion poubelle) et des passants (le week end, la nuit)  aussi, la buanderie des voisins est collée à la chambre/bungalow extérieur, mais cela ne nous a pas plus dérangé, c'était vivable. \nNous recommandons vivement se logement aux familles, groupe d'amis qui souhaitent séjourner sur Sydney et plus particulièrement sur Bondi.\nMerci à l'hôte Cat, pour nous avoir permis de passer un agréable séjour dans une maison à Bondi."},
#    {'_id': '187338569',
#     'date': datetime.datetime(2017, 8, 27, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '9410957',
#     'reviewer_name': 'Laura',
#     'comments': "Highly recommend this beautiful place. We booked for a girls' weekend, and we were really happy. The place is very clean, and just perfect for a relaxing holiday near the beach. Cat is a wonderful host and easy to deal with. Plenty to see and do, great access to public transport, and the shower is amazing! Would definitely stay there again. :-)"},
#    {'_id': '189785015',
#     'date': datetime.datetime(2017, 9, 2, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '97166965',
#     'reviewer_name': 'Leeshii',
#     'comments': 'This house is so zen. The rooms are gorgeous, it has such a great vibe and set up. The bath tub is awesome, the kitchen has everything you need. The location is perfect, close to everything. Cat is the perfect host, very reliable and flexible. We all had the best time.'},
#    {'_id': '192115013',
#     'date': datetime.datetime(2017, 9, 9, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '10277441',
#     'reviewer_name': 'Julie',
#     'comments': 'What a great house. Close to everything Bondi has to offer. We loved the beach and the beach hotel. \nReally well equipped and very clean. Great big comfortable beds and great little extras. Thanks to Cat for the early check-in, it all went without a hitch. \nSee you next time!'},
#    {'_id': '194376880',
#     'date': datetime.datetime(2017, 9, 16, 4, 0),
#     'listing_id': '10423504',
#     'reviewer_id': '9270393',
#     'reviewer_name': 'Erin',
# ...
#     'comments': "My wife and our 2 children stayed in the apartment for a week. It was perfect for us. Great location very close to MTR and in the middle of busy Causeway Bay. Wjile the apartment was small by western standards it was good for us and gave everybody their own space. A much better option than a hotel. The fridge and small kitchen were functional and allowed us to prepare small snacks and breakfast if we wanted. Let's face it you will be mainly eating out in HK. All communication with Susann, Joanna & Szilvi was prompt, professional and helpful. We would recommend highly."},
#    {'_id': '8625089',
#     'date': datetime.datetime(2013, 11, 9, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '4802374',
#     'reviewer_name': 'Christoph',
#     'comments': 'Perfect apartment in the Center of Honkong island, we enjoyed our stay for 4 days and I can recommend 100%. The service prior arriving is well organized. I plan to come again for the next exhibition. '},
#    {'_id': '10190870',
#     'date': datetime.datetime(2014, 2, 5, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '9511036',
#     'reviewer_name': 'Tze',
#     'comments': "Everything went well from the beginning. We got picked up by the driver and arrived safely at the apartment. The host was awesome and she kept our luggages after we checked out which, I am extremely grateful. The apartment was typical HK, small, cosy, efficient use of space and in a perfect location. Only downside is there isn't a safe deposit as advertised but didn't bother me much.  Would recommend as well as return again!"},
#    {'_id': '10457695',
#     'date': datetime.datetime(2014, 2, 19, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '4101892',
#     'reviewer_name': 'Mike',
#     'comments': 'Our trip to Hong Kong could not have been a better experience and many of those thanks were due to the hospitality of Susann and her team. There were four of us arriving throughout different points of the night and having an apartment with an electronic code vice keys was extremely helpful. The apartment was clean, and the beds were very soft. This was my third stay in HK and in comparison to the other apartments this was slightly bigger than average. Located in Causeway Bay, there are tons of shops around and you are easily within walking distance to michelin star rated dim sum (at which we ate at twice in four days). Susann and Alessandra were extremely thorough, with an extensive helpbook provided to cover all your needs from dry cleaning to police to food. I highly recommend staying at this location, as everyone involved was extremely communicative and helpful! I would definitely stay here again, as I plan on continuing to visit my favorite city throughout Asia.'},
#    {'_id': '15527247',
#     'date': datetime.datetime(2014, 7, 11, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '8791849',
#     'reviewer_name': 'Ross',
#     'comments': 'The overall experience was great. Susann was very communicative and supportive of our requests.  Via who was our local point of contact was also very welcoming and helpful.  The apartment is a good size by Hong Kong standards.  It had all the amenities as described and I appreciated that a blender was added to the kitchen appliances.  The location is very convenient to local shopping and MTR.   \r\n\r\nThe only challenge was that the bedrooms have very poor curtain blinds that dont block the light so there is no let up from the lights from the next door buildings and the 6am sunrise.\r\n\r\nthanks again for a wonderful stay!\r\n'},
#    {'_id': '16846738',
#     'date': datetime.datetime(2014, 8, 3, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '1437701',
#     'reviewer_name': 'Alan',
#     'comments': "My friends and I had a fantastic time at Susann's place. The location is incredible and the apartment was comfortable to fit three adults. I would highly recommend this place!"},
#    {'_id': '22183206',
#     'date': datetime.datetime(2014, 11, 1, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '20048166',
#     'reviewer_name': 'Indra',
#     'comments': 'The response from the host especially prior to check in is very prompt and very accommodating with our requests. Perfect apartment for a family holiday in Hong Kong. Location is excellent, close to the MTR, shops and restaurants. The concierge/pick up services I think is just as good as major hotels. The security of the flat is also very good and certainly felt very safe. The flat was well appointed and Via, our local contact was very helpful and accommodating. All in all, a great experience!'},
#    {'_id': '24859731',
#     'date': datetime.datetime(2015, 1, 3, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '21595757',
#     'reviewer_name': 'Katherine',
#     'comments': 'We stayed 3 nights at POSHandGO apartment and  the location was great. Walking distance to mall, shop, eateries, bus stop, MTR station, etc. The apartment building was next to Cafe de Coral and Food Republic; so nothing to worry when it came to meal time. The host was very courteous. Overall, we had a wonderful holiday experience =)'},
#    {'_id': '25173037',
#     'date': datetime.datetime(2015, 1, 8, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '23648214',
#     'reviewer_name': 'Anurag',
#     'comments': 'We had an amazing time at Susan place. We were picked up promptly from Airport. Via was very helpful. She even provided us a baby stroller than we needed for a few days. The apartment was cozy. The best thing about this place is location. Just 1 min to MTR and Hysan Place Mall..'},
#    {'_id': '25770674',
#     'date': datetime.datetime(2015, 1, 25, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '8183470',
#     'reviewer_name': '晓黎',
#     'comments': 'Susann is the best host! Love her!she haves me much help ,and she is so nice .the house is very beautiful more than the picture ,room is very clean ,and the bed is very comfortable,very quite,we sleep very well all the night ,downstairs has much more delicious restaurants ,great location!I will be here when I next time come to hong kong !susann and via makes us so warm and welcomed !'},
#    {'_id': '34259976',
#     'date': datetime.datetime(2015, 6, 6, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '24967525',
#     'reviewer_name': 'Chanel',
#     'comments': 'absoluly highly recommend! First, great location: expecially for family trip. very near MTR and all the best shopping area in HK. Second, check in & out are both convenient, Via is helpful and also Susanna, sweet host they are. come to pick up us with the heavy luggage. Finally, the apartment is useful as HK size is always cozy but, here, totally enough space for us (three adults and two kids). we will definely come back again for such family trip. '},
#    {'_id': '34910990',
#     'date': datetime.datetime(2015, 6, 13, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '7588873',
#     'reviewer_name': 'Fiona',
#     'comments': "The space in HK is limited, but Susann's kindness and hospitality is unlimited . She's the best host and her apartment is very nice. It is a harbor for us while we stayed in HK. She always understand our difficulties and offered her help immediately. \nThank you Susann. Just like my daughter said, we like you and your apartment. "},
#    {'_id': '45168110',
#     'date': datetime.datetime(2015, 8, 31, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '40445923',
#     'reviewer_name': 'Cheri',
#     'comments': 'Affordable rates. Conveniently located in front of Hysan Place. Where Times Square is also of walking distance. The apartment is nice and clean. Complete with kitchen utensils. A/C works great. The only problem is that the toilets were too small; some of the faucets were broken and the doorknobs of the bedrooms could not be locked.'},
#    {'_id': '53900987',
#     'date': datetime.datetime(2015, 11, 14, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '40332648',
#     'reviewer_name': '佳佳',
#     'comments': '房子的地理位置很好,房子很干净,三个房间装修都不错｡'},
#    {'_id': '54038368',
#     'date': datetime.datetime(2015, 11, 15, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '40332648',
#     'reviewer_name': '佳佳',
#     'comments': '房子很好很干净'},
#    {'_id': '58816127',
#     'date': datetime.datetime(2016, 1, 5, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '37556434',
#     'reviewer_name': 'Clara',
#     'comments': 'This is my first experience with Airbnb and it was wonderful. Suzann is very helpful right from the beginning｡The apartment was nice and comfort as pictured , location is the best, right at the center of causeway bay.  '},
#    {'_id': '59576567',
#     'date': datetime.datetime(2016, 1, 12, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '49850448',
#     'reviewer_name': 'S',
#     'comments': 'nice apartment!great location!everything is perfect, but the washing room is small. I love the apartment!'},
#    {'_id': '64335692',
#     'date': datetime.datetime(2016, 3, 2, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '28268578',
#     'reviewer_name': 'Killy',
#     'comments': 'It was a very good location for traveler. And Susan is really nice and have very good introduction of her house. Great experience.'},
#    {'_id': '65279018',
#     'date': datetime.datetime(2016, 3, 12, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '61172316',
#     'reviewer_name': 'Ralph',
#     'comments': 'Appartement tres bien situe, propre, bien equipe, rien a dire........\r\nSuper en general'},
#    {'_id': '71778245',
#     'date': datetime.datetime(2016, 4, 28, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '62711649',
#     'reviewer_name': 'Kim',
#     'comments': 'Great apartment in a fabulous location - MTR right next door, a million places to eat, shop and explore right at our doorstep. Apartment well equipped and perfect for our needs. Good communication with host and great apartment manual with heaps of information. Thank you very much for having us, we would certainly recommend your apartment to others. '},
#    {'_id': '80811973',
#     'date': datetime.datetime(2016, 6, 19, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '62731278',
#     'reviewer_name': 'Linda',
#     'comments': 'Pros: Location, space, beds were comfortable, ample kitchen utensils and equipment. Nice big tv. Hosts were great as they constantly kept in touch and made sure everything was smooth right up to arrival. Susann and Via were also easily contactable. They were also very kind to provide a cot and high chair for my toddler.\r\nCons: Cleanliness as the toilets had smell and mold; Floors had hair and dust. Furniture like the glass tables should be changed especially if guests had young kids.\r\n'},
#    {'_id': '134374186',
#     'date': datetime.datetime(2017, 2, 26, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '31735795',
#     'reviewer_name': 'Rachel',
#     'comments': 'A great location in Hong Kong.  The airport pick up was an added bonus!'},
#    {'_id': '135053824',
#     'date': datetime.datetime(2017, 3, 2, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '113188692',
#     'reviewer_name': 'David',
#     'comments': 'Great location...good value'},
#    {'_id': '141394034',
#     'date': datetime.datetime(2017, 4, 2, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '38938976',
#     'reviewer_name': 'A\\\\W',
#     'comments': 'ที่พักเดินทางสะดวก ใกล้ MRT และแหล่งชอปปิ้ง ที่พักดีงามคะ'},
#    {'_id': '147457378',
#     'date': datetime.datetime(2017, 4, 26, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '81444278',
#     'reviewer_name': 'Go',
#     'comments': 'Clean and beautiful interior design.\nThe host is very kind and helpful for staying in the apartment. Quick response for our questions and detailed explanations about apartment. Easy to get the subway station.\nIf I have chance to visit Hong Kong again, I would chose this apartment again.\nThank you!!'},
#    {'_id': '149013431',
#     'date': datetime.datetime(2017, 5, 2, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '51905521',
#     'reviewer_name': 'Ting Ling',
#     'comments': 'Complimentary Airport Pick-Up is the bonus & reason for me to book this apartment. The location is considered strategic, which located in Causeway Bay & opposite Hysan Place. You can take the MTR at the basement floor of Hysan Place. SOGO & Times Square are within walking distance. 3 rooms, 3 double beds, 1 sofa in the living room, which maximum can fit 7 people. 2 small washrooms. Not very spacious but for the house in Hong Kong, I think you cannot expect it will be very big. Late check-out will need to pay an additional fee of HKD100 per hour so that we had to drag our luggage around until our boarding time at night, which makes our trip even tiring. Some hosts will allow us to put our luggage at their place and collect it when we are heading to the airport, so it will be easier for the traveller whose flight is at night time.'},
#    {'_id': '169022897',
#     'date': datetime.datetime(2017, 7, 11, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '299486',
#     'reviewer_name': 'Sarah',
#     'comments': 'location of the flat was great. right in the heart of causeway bay. flat is quite spacious for hongkong standard :D\nsusann is very helpful and responsive.\nflat was well equipped and clean.\nthe only down side was the ACs in all rooms were very loud. had to use earplugs to sleep'},
#    {'_id': '173819551',
#     'date': datetime.datetime(2017, 7, 24, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '55847701',
#     'reviewer_name': '家俨',
#     'comments': '住这个公寓简直就是噩梦｡房间的实际样子和看到图片的差别很大｡公寓整体很小,卫生间和房间都比图片小很多,住5个人,非常的拥挤｡房子很旧很脏,有很多 (Hidden by Airbnb) 还有蟑螂｡有一个小房间的窗户打开外面是非常脏的画面,而且房间早上有很大很大的油烟味道,可能对面是别人家的厨房｡入住期间基本没有睡｡非常难受｡总而言之,这是我用airbnb定房间以来最差的一次,特别特别糟糕｡但是这些不满仅仅是针对这个房子｡房东SusanC还是非常好的 给我提供了很多的帮助｡房子的位置非常好,在时代广场和sogo的中间'},
#    {'_id': '191515974',
#     'date': datetime.datetime(2017, 9, 8, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '9573509',
#     'reviewer_name': 'Lesley',
#     'comments': 'Great location! Pics were accurate and communication was easy. Will definitely stay again! Thank you!'},
#    {'_id': '210025437',
#     'date': datetime.datetime(2017, 11, 7, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '156723546',
#     'reviewer_name': 'Juliette',
#     'comments': 'Very clear comms and reactive response from Susann, apartment is centrally located - ideal for a short stay to enjoy Causeway bay shopping area.'},
#    {'_id': '223883732',
#     'date': datetime.datetime(2018, 1, 2, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '147516507',
#     'reviewer_name': 'Raymond',
#     'comments': 'The place is very conveniently located, security is good and real quiet even though it is in an busy area. However, lack of space for luggages and the poor drainage in the shower stalls should require immediate attention.'},
#    {'_id': '231017743',
#     'date': datetime.datetime(2018, 1, 30, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '150204023',
#     'reviewer_name': 'Yulia',
#     'comments': 'Fast response. Susan and her team is kind person. Overall nice... thanks once again'},
#    {'_id': '233288674',
#     'date': datetime.datetime(2018, 2, 9, 5, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '170871854',
#     'reviewer_name': 'SangHyun',
#     'comments': '2018.02.07~09일(2일, 8명)동안 숙박했습니다.\n숙소 위치는 센트럴로 바로 갈 수 있는 지하철역에서 매우 가깝습니다.\n그리고 숙소 근처에 식당(맥도날드 및 로컬푸드 등)이 많고, 숙소는 매우 안전합니다.\n화장실 및 샤워시설이 두개로 충분했습니다.\n "Kris " 및 "Susann"이 숙소 주변 안내 및 숙소 내 시설 활용방법에 대해 매우 잘 설명해 줬습니다.\n다시 홍콩을 방문한다면, 이 숙소를 가장먼저 고려할 것입니다.'},
#    {'_id': '298045918',
#     'date': datetime.datetime(2018, 7, 29, 4, 0),
#     'listing_id': '1176693',
#     'reviewer_id': '130888575',
#     'reviewer_name': 'Yuanmei',
#     'comments': 'Very nice, cute and clean place! The location is super convenience. Close to subway, shopping and many choices for food. The building has 24 hours security. Susann and Kris are very friendly and helpful! We enjoy the staying very much!'}]}]

# %% [markdown]
# Puedes encontrar más documentación sobre la librería `pymongo` en https://api.mongodb.com/python/current/
