# %% [markdown]
# Queremos predecir la probabilidad de que nos suban el sueldo. Buscamos a 10 empleados y generamos el siguiente dataset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'Sueldo':[20,30,18,32,22,54,50,19,26,32],
                 'Antiguedad':[1,5,3,7,12,9,4,2,1,4],
                 'Ascenso':[1,0,1,1,1,0,0,0,1,0]})

df

# %% [markdown]
# Vamos a programarlo en Python con $\alpha=0.001$, e inicializando aleatoriamente los parámetros $w_0=0.3$, $w_1=-1$ y $w_2=0.2$

# %% [markdown]
# ¿Cuál es la predición inicial?

# %%
# Define la función sigmoide

# %%
# Crea un array con los pesos

# %%
# Crea la matriz X incluyendo una columna de 1s

# %%
# Calcula las probabilidades

# %%
# Calcula las predicciones (1 si probabilidad>0.5)

# %% [markdown]
# ![image.png](attachment:image.png)
# ¿Es el mejor modelo?

# %% [markdown]
# Apliquemos el algoritmo de Gradient Descent para buscar los coeficientes óptimos

# %%
# Cambia la variable objetivo a -1 y 1

# %% [markdown]
# Define la función de error

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Calculamos el gradiente

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Calcula las probabilidades

# %% [markdown]
# Utilizando la librería `sklearn`
